# %% [markdown]
# Importing Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#import data - orders
df_ords = pd.read_csv(r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Original Data/orders.csv', index_col = False)

# %%
#import data - products
df_prods = pd.read_csv(r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Original Data/products.csv')

# %%
#import data - departments
df_dep = pd.read_csv(r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Original Data/departments.csv')

# %%
#Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
#Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the data frame.
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
#Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# The busiest hour is 10, with 288418 orders.

# %%
#Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.

# %%
df_prods = pd.read_csv(r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Original Data/products.csv')

# %%
data_dict = df_prods.to_dict('index')

# %%
data_dict
# Out:
# {0: {'product_id': 1,
#   'product_name': 'Chocolate Sandwich Cookies',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 5.8},
#  1: {'product_id': 2,
#   'product_name': 'All-Seasons Salt',
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 9.3},
#  2: {'product_id': 3,
#   'product_name': 'Robust Golden Unsweetened Oolong Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 4.5},
#  3: {'product_id': 4,
#   'product_name': 'Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 10.5},
#  4: {'product_id': 5,
#   'product_name': 'Green Chile Anytime Sauce',
#   'aisle_id': 5,
#   'department_id': 13,
#   'prices': 4.3},
#  5: {'product_id': 6,
#   'product_name': 'Dry Nose Oil',
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 2.6},
#  6: {'product_id': 7,
#   'product_name': 'Pure Coconut Water With Orange',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 4.4},
#  7: {'product_id': 8,
#   'product_name': "Cut Russet Potatoes Steam N' Mash",
#   'aisle_id': 116,
#   'department_id': 1,
#   'prices': 1.1},
#  8: {'product_id': 9,
#   'product_name': 'Light Strawberry Blueberry Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 7.0},
#  9: {'product_id': 10,
#   'product_name': 'Sparkling Orange Juice & Prickly Pear Beverage',
#   'aisle_id': 115,
#   'department_id': 7,
#   'prices': 8.4},
#  10: {'product_id': 11,
#   'product_name': 'Peach Mango Juice',
#   'aisle_id': 31,
#   'department_id': 7,
#   'prices': 2.8},
#  11: {'product_id': 12,
#   'product_name': 'Chocolate Fudge Layer Cake',
#   'aisle_id': 119,
#   'department_id': 1,
#   'prices': 9.4},
#  12: {'product_id': 13,
#   'product_name': 'Saline Nasal Mist',
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 1.1},
#  13: {'product_id': 14,
#   'product_name': 'Fresh Scent Dishwasher Cleaner',
#   'aisle_id': 74,
#   'department_id': 17,
#   'prices': 6.5},
#  14: {'product_id': 15,
#   'product_name': 'Overnight Diapers Size 6',
#   'aisle_id': 56,
#   'department_id': 18,
#   'prices': 11.2},
#  15: {'product_id': 16,
#   'product_name': 'Mint Chocolate Flavored Syrup',
#   'aisle_id': 103,
#   'department_id': 19,
#   'prices': 5.2},
#  16: {'product_id': 17,
#   'product_name': 'Rendered Duck Fat',
#   'aisle_id': 35,
#   'department_id': 12,
#   'prices': 17.1},
#  17: {'product_id': 18,
#   'product_name': 'Pizza for One Suprema  Frozen Pizza',
#   'aisle_id': 79,
#   'department_id': 1,
#   'prices': 10.6},
#  18: {'product_id': 19,
#   'product_name': 'Gluten Free Quinoa Three Cheese & Mushroom Blend',
#   'aisle_id': 63,
#   'department_id': 9,
#   'prices': 12.0},
#  19: {'product_id': 20,
#   'product_name': 'Pomegranate Cranberry & Aloe Vera Enrich Drink',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 6.0},
#  20: {'product_id': 21,
#   'product_name': 'Small & Medium Dental Dog Treats',
#   'aisle_id': 40,
#   'department_id': 8,
#   'prices': 10.0},
#  21: {'product_id': 22,
#   'product_name': 'Fresh Breath Oral Rinse Mild Mint',
#   'aisle_id': 20,
#   'department_id': 11,
#   'prices': 9.5},
#  22: {'product_id': 23,
#   'product_name': 'Organic Turkey Burgers',
#   'aisle_id': 49,
#   'department_id': 12,
#   'prices': 8.2},
#  23: {'product_id': 24,
#   'product_name': 'Tri-Vi-Sol® Vitamins A-C-and D Supplement Drops for Infants',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 9.1},
#  24: {'product_id': 25,
#   'product_name': 'Salted Caramel Lean Protein & Fiber Bar',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 1.9},
#  25: {'product_id': 26,
#   'product_name': 'Fancy Feast Trout Feast Flaked Wet Cat Food',
#   'aisle_id': 41,
#   'department_id': 8,
#   'prices': 11.3},
#  26: {'product_id': 27,
#   'product_name': 'Complete Spring Water Foaming Antibacterial Hand Wash',
#   'aisle_id': 127,
#   'department_id': 11,
#   'prices': 5.3},
#  27: {'product_id': 28,
#   'product_name': 'Wheat Chex Cereal',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 10.1},
#  28: {'product_id': 29,
#   'product_name': 'Fresh Cut Golden Sweet No Salt Added Whole Kernel Corn',
#   'aisle_id': 81,
#   'department_id': 15,
#   'prices': 6.8},
#  29: {'product_id': 30,
#   'product_name': 'Three Cheese Ziti, Marinara with Meatballs',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 13.8},
#  30: {'product_id': 31,
#   'product_name': 'White Pearl Onions',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 7.5},
#  31: {'product_id': 32,
#   'product_name': 'Nacho Cheese White Bean Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 4.9},
#  32: {'product_id': 33,
#   'product_name': 'Organic Spaghetti Style Pasta',
#   'aisle_id': 131,
#   'department_id': 9,
#   'prices': 12.6},
#  33: {'product_id': 34,
#   'product_name': nan,
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 12.2},
#  34: {'product_id': 35,
#   'product_name': 'Italian Herb Porcini Mushrooms Chicken Sausage',
#   'aisle_id': 106,
#   'department_id': 12,
#   'prices': 15.1},
#  35: {'product_id': 36,
#   'product_name': 'Traditional Lasagna with Meat Sauce Savory Italian Recipes',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 1.3},
#  36: {'product_id': 37,
#   'product_name': 'Noodle Soup Mix With Chicken Broth',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 9.2},
#  37: {'product_id': 38,
#   'product_name': 'Ultra Antibacterial Dish Liquid',
#   'aisle_id': 100,
#   'department_id': 21,
#   'prices': 13.4},
#  38: {'product_id': 39,
#   'product_name': 'Daily Tangerine Citrus Flavored Beverage',
#   'aisle_id': 64,
#   'department_id': 7,
#   'prices': 12.5},
#  39: {'product_id': 40,
#   'product_name': 'Beef Hot Links Beef Smoked Sausage With Chile Peppers',
#   'aisle_id': 106,
#   'department_id': 12,
#   'prices': 22.5},
#  40: {'product_id': 41,
#   'product_name': 'Organic Sourdough Einkorn Crackers Rosemary',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 6.5},
#  41: {'product_id': 42,
#   'product_name': 'Biotin 1000 mcg',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 9.0},
#  42: {'product_id': 43,
#   'product_name': 'Organic Clementines',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 11.5},
#  43: {'product_id': 44,
#   'product_name': 'Sparkling Raspberry Seltzer',
#   'aisle_id': 115,
#   'department_id': 7,
#   'prices': 12.2},
#  44: {'product_id': 45,
#   'product_name': 'European Cucumber',
#   'aisle_id': 83,
#   'department_id': 4,
#   'prices': 14.3},
#  45: {'product_id': 46,
#   'product_name': 'Raisin Cinnamon Bagels 5 count',
#   'aisle_id': 58,
#   'department_id': 1,
#   'prices': 14.6},
#  46: {'product_id': 47,
#   'product_name': 'Onion Flavor Organic Roasted Seaweed Snack',
#   'aisle_id': 66,
#   'department_id': 6,
#   'prices': 7.7},
#  47: {'product_id': 48,
#   'product_name': 'School Glue, Washable, No Run',
#   'aisle_id': 87,
#   'department_id': 17,
#   'prices': 6.4},
#  48: {'product_id': 49,
#   'product_name': 'Vegetarian Grain Meat Sausages Italian - 4 CT',
#   'aisle_id': 14,
#   'department_id': 20,
#   'prices': 10.1},
#  49: {'product_id': 50,
#   'product_name': 'Pumpkin Muffin Mix',
#   'aisle_id': 105,
#   'department_id': 13,
#   'prices': 11.3},
#  50: {'product_id': 51,
#   'product_name': 'Sa Extra Hold Mousse Hair Styling',
#   'aisle_id': 22,
#   'department_id': 11,
#   'prices': 5.3},
#  51: {'product_id': 52,
#   'product_name': 'Mirabelle Brut Rose',
#   'aisle_id': 134,
#   'department_id': 5,
#   'prices': 14.4},
#  52: {'product_id': 53,
#   'product_name': 'Whole Leaf Pure Aloe With Lemon Juice',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 4.7},
#  53: {'product_id': 54,
#   'product_name': '24/7 Performance Cat Litter',
#   'aisle_id': 41,
#   'department_id': 8,
#   'prices': 12.9},
#  54: {'product_id': 55,
#   'product_name': 'Lasting Color Shampoo',
#   'aisle_id': 22,
#   'department_id': 11,
#   'prices': 8.8},
#  55: {'product_id': 56,
#   'product_name': 'Healthy Pop Butter Popcorn',
#   'aisle_id': 23,
#   'department_id': 19,
#   'prices': 4.4},
#  56: {'product_id': 57,
#   'product_name': 'Flat Toothpicks',
#   'aisle_id': 111,
#   'department_id': 17,
#   'prices': 13.2},
#  57: {'product_id': 58,
#   'product_name': 'Whole Wheat Tortillas',
#   'aisle_id': 128,
#   'department_id': 3,
#   'prices': 6.7},
#  58: {'product_id': 59,
#   'product_name': 'Medium Taqueria Style Chipotle Salsa',
#   'aisle_id': 50,
#   'department_id': 19,
#   'prices': 6.8},
#  59: {'product_id': 60,
#   'product_name': 'Cheesy Creations Roasted Garlic Parmesan Sauce',
#   'aisle_id': 9,
#   'department_id': 9,
#   'prices': 10.0},
#  60: {'product_id': 61,
#   'product_name': 'Ramen Noodles Soup Chicken Mushroom Flavor',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 15.0},
#  61: {'product_id': 62,
#   'product_name': 'Premium Deli Oven Roasted Turkey Breast',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 14.6},
#  62: {'product_id': 63,
#   'product_name': 'Banana & Sweet Potato Organic Teething Wafers',
#   'aisle_id': 92,
#   'department_id': 18,
#   'prices': 13.4},
#  63: {'product_id': 64,
#   'product_name': "Autumn Vegetable & Turkey Dinner with Lil' Bits Purees Dinner",
#   'aisle_id': 92,
#   'department_id': 18,
#   'prices': 13.6},
#  64: {'product_id': 65,
#   'product_name': 'Organic Red Wine & Olive Oil Dressing Organic',
#   'aisle_id': 89,
#   'department_id': 13,
#   'prices': 12.4},
#  65: {'product_id': 66,
#   'product_name': 'European Style Spring Mix',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 11.7},
#  66: {'product_id': 67,
#   'product_name': 'Jelly, Blackberry',
#   'aisle_id': 88,
#   'department_id': 13,
#   'prices': 4.9},
#  67: {'product_id': 68,
#   'product_name': 'Pancake Mix, Buttermilk',
#   'aisle_id': 130,
#   'department_id': 14,
#   'prices': 13.7},
#  68: {'product_id': 69,
#   'product_name': nan,
#   'aisle_id': 26,
#   'department_id': 7,
#   'prices': 11.8},
#  69: {'product_id': 70,
#   'product_name': 'Sweet Cooking Rice Seasoning',
#   'aisle_id': 66,
#   'department_id': 6,
#   'prices': 5.0},
#  70: {'product_id': 71,
#   'product_name': 'Ultra 7 Inch Polypropylene Traditional Plates',
#   'aisle_id': 111,
#   'department_id': 17,
#   'prices': 11.7},
#  71: {'product_id': 72,
#   'product_name': 'Organic Honeycrisp Apples',
#   'aisle_id': 100,
#   'department_id': 21,
#   'prices': 10.7},
#  72: {'product_id': 73,
#   'product_name': 'Jasmine Tea Unfiltered Ginger Ale',
#   'aisle_id': 77,
#   'department_id': 7,
#   'prices': 8.3},
#  73: {'product_id': 74,
#   'product_name': "Artisan Chick'n & Apple Sausage",
#   'aisle_id': 14,
#   'department_id': 20,
#   'prices': 3.0},
#  74: {'product_id': 75,
#   'product_name': 'Hemp Protein, Organic',
#   'aisle_id': 65,
#   'department_id': 11,
#   'prices': 9.0},
#  75: {'product_id': 76,
#   'product_name': 'Spinach Basil Garlic Linguini',
#   'aisle_id': 12,
#   'department_id': 9,
#   'prices': 9.7},
#  76: {'product_id': 77,
#   'product_name': 'Coconut Chocolate Chip Energy Bar',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 6.4},
#  77: {'product_id': 78,
#   'product_name': 'Nutter Butter Cookie Bites Go-Pak',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 3.0},
#  78: {'product_id': 79,
#   'product_name': 'Wild Albacore Tuna No Salt Added',
#   'aisle_id': 95,
#   'department_id': 15,
#   'prices': 14.0},
#  79: {'product_id': 80,
#   'product_name': 'French  Tarragon Wine Vinegar',
#   'aisle_id': 19,
#   'department_id': 13,
#   'prices': 1.9},
#  80: {'product_id': 81,
#   'product_name': 'Blakes Chicken Parmesan Dinner',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 9.4},
#  81: {'product_id': 82,
#   'product_name': 'All Natural 100% Apple Juice',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 6.4},
#  82: {'product_id': 83,
#   'product_name': '100% Whole Wheat Pita Bread',
#   'aisle_id': 128,
#   'department_id': 3,
#   'prices': 14.4},
#  83: {'product_id': 84,
#   'product_name': 'Lamb Shank',
#   'aisle_id': 7,
#   'department_id': 12,
#   'prices': 24.3},
#  84: {'product_id': 85,
#   'product_name': 'Soppressata Piccante',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 8.9},
#  85: {'product_id': 86,
#   'product_name': 'Camilia, Single Liquid Doses',
#   'aisle_id': 6,
#   'department_id': 2,
#   'prices': 12.4},
#  86: {'product_id': 87,
#   'product_name': 'Classics Earl Grey Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 9.1},
#  87: {'product_id': 88,
#   'product_name': 'Probiotics High Potency Capsules',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 8.2},
#  88: {'product_id': 89,
#   'product_name': 'Yogurt Fruit Dip Sliced Apples',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 12.6},
#  89: {'product_id': 90,
#   'product_name': 'Smorz Cereal',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 3.9},
#  90: {'product_id': 91,
#   'product_name': 'Kind Prenatal Once Daily',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 6.3},
#  91: {'product_id': 92,
#   'product_name': 'Meat In The Middle Large Rawhide Chews',
#   'aisle_id': 40,
#   'department_id': 8,
#   'prices': 10.5},
#  92: {'product_id': 93,
#   'product_name': 'Uncured Cracked Pepper Beef',
#   'aisle_id': 23,
#   'department_id': 19,
#   'prices': 2.4},
#  93: {'product_id': 94,
#   'product_name': 'Organic Blueberry Blitz Fruit & Veggie Smoothie Mashups',
#   'aisle_id': 92,
#   'department_id': 18,
#   'prices': 2.8},
#  94: {'product_id': 95,
#   'product_name': 'Organic Rice Vinegar',
#   'aisle_id': 66,
#   'department_id': 6,
#   'prices': 5.6},
#  95: {'product_id': 96,
#   'product_name': 'Sprinklez Confetti Fun Organic Toppings',
#   'aisle_id': 97,
#   'department_id': 13,
#   'prices': 12.9},
#  96: {'product_id': 97,
#   'product_name': 'Organic Chamomile Lemon Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 8.4},
#  97: {'product_id': 98,
#   'product_name': '2% Yellow American Cheese',
#   'aisle_id': 2,
#   'department_id': 16,
#   'prices': 4.5},
#  98: {'product_id': 99,
#   'product_name': 'Local Living Butter Lettuce',
#   'aisle_id': 83,
#   'department_id': 4,
#   'prices': 10.0},
#  99: {'product_id': 100,
#   'product_name': 'Peanut Butter & Strawberry Jam Sandwich',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 4.7},
#  100: {'product_id': 101,
#   'product_name': 'Bread, Healthy Whole Grain',
#   'aisle_id': 112,
#   'department_id': 3,
#   'prices': 5.2},
#  101: {'product_id': 102,
#   'product_name': 'Danish Butter Cookies',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 5.5},
#  102: {'product_id': 103,
#   'product_name': 'Sprouted Kale Cracker',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 6.4},
#  103: {'product_id': 104,
#   'product_name': 'High Fiber Tomato Basil Soup',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 5.0},
#  104: {'product_id': 105,
#   'product_name': 'Easy Grab 9\\"x13\\" Oblong Glass Bakeware',
#   'aisle_id': 10,
#   'department_id': 17,
#   'prices': 7.6},
#  105: {'product_id': 106,
#   'product_name': 'Organic Yummy Tummy Maple & Brown Sugar Instant Oatmeal',
#   'aisle_id': 92,
#   'department_id': 18,
#   'prices': 5.2},
#  106: {'product_id': 107,
#   'product_name': 'Mild Salsa Divino',
#   'aisle_id': 51,
#   'department_id': 13,
#   'prices': 11.6},
#  107: {'product_id': 108,
#   'product_name': 'Organic Sprouted Barley Bread',
#   'aisle_id': 112,
#   'department_id': 3,
#   'prices': 14.4},
#  108: {'product_id': 109,
#   'product_name': 'Grape Leaf Hummus Wrap',
#   'aisle_id': 13,
#   'department_id': 20,
#   'prices': 7.1},
#  109: {'product_id': 110,
#   'product_name': 'Uncured Turkey Bologna',
#   'aisle_id': 100,
#   'department_id': 21,
#   'prices': 7.6},
#  110: {'product_id': 111,
#   'product_name': 'Fabric Softener, Geranium Scent',
#   'aisle_id': 75,
#   'department_id': 17,
#   'prices': 5.6},
#  111: {'product_id': 112,
#   'product_name': 'Hot Tomatillo Salsa',
#   'aisle_id': 51,
#   'department_id': 13,
#   'prices': 6.2},
#  112: {'product_id': 113,
#   'product_name': "Infant's Blend Probiotic",
#   'aisle_id': 70,
#   'department_id': 11,
#   'prices': 12.6},
#  113: {'product_id': 114,
#   'product_name': 'Light Savory Beef Barley Vegetable Soup',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 5.7},
#  114: {'product_id': 115,
#   'product_name': 'Scooby-Doo! Fruit Flavored Snacks',
#   'aisle_id': 50,
#   'department_id': 19,
#   'prices': 2.7},
#  115: {'product_id': 116,
#   'product_name': nan,
#   'aisle_id': 93,
#   'department_id': 3,
#   'prices': 10.8},
#  116: {'product_id': 117,
#   'product_name': 'Petit Suisse Fruit',
#   'aisle_id': 2,
#   'department_id': 16,
#   'prices': 3.1},
#  117: {'product_id': 118,
#   'product_name': 'Ground Turkey Chub',
#   'aisle_id': 34,
#   'department_id': 1,
#   'prices': 15.0},
#  118: {'product_id': 119,
#   'product_name': 'Chardonnay Paso Robles',
#   'aisle_id': 62,
#   'department_id': 5,
#   'prices': 5.5},
#  119: {'product_id': 120,
#   'product_name': 'Cauliflower Florettes',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 2.3},
#  120: {'product_id': 121,
#   'product_name': 'Sharp Cheddar',
#   'aisle_id': 21,
#   'department_id': 16,
#   'prices': 8.1},
#  121: {'product_id': 122,
#   'product_name': 'Pomegranate Molasses',
#   'aisle_id': 29,
#   'department_id': 13,
#   'prices': 9.6},
#  122: {'product_id': 123,
#   'product_name': 'Sherry Reserve Vinegar',
#   'aisle_id': 19,
#   'department_id': 13,
#   'prices': 5.8},
#  123: {'product_id': 124,
#   'product_name': 'Sun Cups Dark Chocolate',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 3.0},
#  124: {'product_id': 125,
#   'product_name': 'Herbal Armor DEET-Free Natural Insect Repellant',
#   'aisle_id': 118,
#   'department_id': 11,
#   'prices': 7.5},
#  125: {'product_id': 126,
#   'product_name': 'Hot & Spicy Chicken Flavor Ramen Noodles',
#   'aisle_id': 4,
#   'department_id': 9,
#   'prices': 14.8},
#  126: {'product_id': 127,
#   'product_name': 'Marscapone',
#   'aisle_id': 108,
#   'department_id': 16,
#   'prices': 3.5},
#  127: {'product_id': 128,
#   'product_name': 'Organic Wild Blueberries',
#   'aisle_id': 116,
#   'department_id': 1,
#   'prices': 14.3},
#  128: {'product_id': 129,
#   'product_name': 'Traditional Chicken & Orzo with Lemon Soup',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 1.7},
#  129: {'product_id': 130,
#   'product_name': 'Vanilla Milk Chocolate Almond Ice Cream Bars Multi-Pack',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 8.2},
#  130: {'product_id': 131,
#   'product_name': 'Brioche Bachelor Loaf',
#   'aisle_id': 93,
#   'department_id': 3,
#   'prices': 11.9},
#  131: {'product_id': 132,
#   'product_name': 'Yogurt Strawberry Pomegranate',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 7.1},
#  132: {'product_id': 133,
#   'product_name': 'Purifying Daily Detox Scrub',
#   'aisle_id': 109,
#   'department_id': 11,
#   'prices': 11.7},
#  133: {'product_id': 134,
#   'product_name': 'Stain Release Boost In-Wash Stain Remover Pacs',
#   'aisle_id': 75,
#   'department_id': 17,
#   'prices': 6.6},
#  134: {'product_id': 135,
#   'product_name': 'Dark Chocolate Ice Cream Topping',
#   'aisle_id': 103,
#   'department_id': 19,
#   'prices': 2.4},
#  135: {'product_id': 136,
#   'product_name': 'Simple',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 5.0},
#  136: {'product_id': 137,
#   'product_name': 'Very Vanilla Soymilk',
#   'aisle_id': 91,
#   'department_id': 16,
#   'prices': 1.2},
#  137: {'product_id': 138,
#   'product_name': 'Olli Napoli Salami',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 5.1},
#  138: {'product_id': 139,
#   'product_name': 'Zita Cut, No. 118',
#   'aisle_id': 131,
#   'department_id': 9,
#   'prices': 11.7},
#  139: {'product_id': 140,
#   'product_name': 'Chips Onion Chipotle Garlic',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 6.9},
#  140: {'product_id': 141,
#   'product_name': 'Restaurant Style Organic Chia & Quinoa Tortilla Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 2.9},
#  141: {'product_id': 142,
#   'product_name': 'Arugula Salad',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 2.4},
#  142: {'product_id': 143,
#   'product_name': 'Organic Lemons',
#   'aisle_id': 24,
#   'department_id': 4,
#   'prices': 12.0},
#  143: {'product_id': 144,
#   'product_name': 'Coarse Grind Garlic Powder & Parsley Blend',
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 2.1},
#  144: {'product_id': 145,
#   'product_name': 'Traditional Water Crackers',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 1.9},
#  145: {'product_id': 146,
#   'product_name': 'Anti Diarrheal Caplets',
#   'aisle_id': 70,
#   'department_id': 11,
#   'prices': 9.6},
#  146: {'product_id': 147,
#   'product_name': 'Organic Ranch Veggie Dip',
#   'aisle_id': 67,
#   'department_id': 20,
#   'prices': 3.4},
#  147: {'product_id': 148,
#   'product_name': 'Nectarines',
#   'aisle_id': 24,
#   'department_id': 4,
#   'prices': 9.3},
#  148: {'product_id': 149,
#   'product_name': 'Wild Blueberry All Natural Fruit Spread',
#   'aisle_id': 88,
#   'department_id': 13,
#   'prices': 10.0},
#  149: {'product_id': 150,
#   'product_name': 'Brut Rosé',
#   'aisle_id': 134,
#   'department_id': 5,
#   'prices': 12.9},
#  150: {'product_id': 151,
#   'product_name': 'Aromatherapaes Stress Reducing Lavender & Chamomile Spa Bath',
#   'aisle_id': 132,
#   'department_id': 11,
#   'prices': 7.5},
#  151: {'product_id': 152,
#   'product_name': '3 in 1 Soap for Every Man, Cucumber & Lemon',
#   'aisle_id': 25,
#   'department_id': 11,
#   'prices': 5.1},
#  152: {'product_id': 153,
#   'product_name': 'Fabric Refresher Meadows & Rain Air Freshener (1 Count, 27 oz)  Air Care',
#   'aisle_id': 75,
#   'department_id': 17,
#   'prices': 11.3},
#  153: {'product_id': 154,
#   'product_name': 'Corn Dogs, Mini, Honey Crunchy Flavor',
#   'aisle_id': 129,
#   'department_id': 1,
#   'prices': 13.4},
#  154: {'product_id': 155,
#   'product_name': 'Artisan Ciabatta',
#   'aisle_id': 58,
#   'department_id': 1,
#   'prices': 2.5},
#  155: {'product_id': 156,
#   'product_name': 'Extra Spearmint Sugar-Free Gum',
#   'aisle_id': 46,
#   'department_id': 19,
#   'prices': 3.5},
#  156: {'product_id': 157,
#   'product_name': 'Living Organic Cilantro',
#   'aisle_id': 16,
#   'department_id': 4,
#   'prices': 7.5},
#  157: {'product_id': 158,
#   'product_name': 'Smoked Ham & Oven Roasted Turkey Sub Sandwich Kit',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 14.0},
#  158: {'product_id': 159,
#   'product_name': 'Calcium Adult Gummy Vitamins, Orange Cherry & Strawberry',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 2.5},
#  159: {'product_id': 160,
#   'product_name': '100% Recycled Aluminum Foil',
#   'aisle_id': 97,
#   'department_id': 13,
#   'prices': 12.7},
#  160: {'product_id': 161,
#   'product_name': 'Hacho Miso Aged & Fermented Soybeans',
#   'aisle_id': 66,
#   'department_id': 6,
#   'prices': 1.2},
#  161: {'product_id': 162,
#   'product_name': 'Organic Mini Homestyle Waffles',
#   'aisle_id': 52,
#   'department_id': 1,
#   'prices': 2.3},
#  162: {'product_id': 163,
#   'product_name': 'Dressing Bleu Cheese',
#   'aisle_id': 89,
#   'department_id': 13,
#   'prices': 9.6},
#  163: {'product_id': 164,
#   'product_name': 'Peanut Butter Cacao Quinoa Clusters',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 5.2},
#  164: {'product_id': 165,
#   'product_name': 'Wild Chanterelle Mushroom Ravioli',
#   'aisle_id': 12,
#   'department_id': 9,
#   'prices': 2.4},
#  165: {'product_id': 166,
#   'product_name': 'Garlic Parmesan Pita Bread Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 5.2},
#  166: {'product_id': 167,
#   'product_name': 'Sparkling Blush Grape Juice',
#   'aisle_id': 77,
#   'department_id': 7,
#   'prices': 13.8},
#  167: {'product_id': 168,
#   'product_name': 'Halves & Pieces Walnuts',
#   'aisle_id': 17,
#   'department_id': 13,
#   'prices': 4.3},
#  168: {'product_id': 169,
#   'product_name': 'Extra Sharp Cheddar Cheese',
#   'aisle_id': 21,
#   'department_id': 16,
#   'prices': 13.1},
#  169: {'product_id': 170,
#   'product_name': 'Single Herbs Ginkgo Leaf Dietary Supplement',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 5.4},
#  170: {'product_id': 171,
#   'product_name': 'Steakhouse Onion Burger with Garlic Seasoning',
#   'aisle_id': 5,
#   'department_id': 13,
#   'prices': 2.9},
#  171: {'product_id': 172,
#   'product_name': 'Gluten Free All Natural Chocolate Chip Cookies',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 4.8},
#  172: {'product_id': 173,
#   'product_name': 'Habanero Lime Shrimp Flavor Ramen Noodle Soup',
#   'aisle_id': 4,
#   'department_id': 9,
#   'prices': 10.2},
#  173: {'product_id': 174,
#   'product_name': 'Vanishing Acne Treatment Cream',
#   'aisle_id': 73,
#   'department_id': 11,
#   'prices': 7.7},
#  174: {'product_id': 175,
#   'product_name': 'T Bone Steak',
#   'aisle_id': 122,
#   'department_id': 12,
#   'prices': 18.6},
#  175: {'product_id': 176,
#   'product_name': 'Original Turkey',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 14.9},
#  176: {'product_id': 177,
#   'product_name': 'Citrus Terere Yerba Mate',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 6.6},
#  177: {'product_id': 178,
#   'product_name': 'Vegan Santa Fe Style Flour Tortilla Rolled Tacos',
#   'aisle_id': 42,
#   'department_id': 1,
#   'prices': 6.2},
#  178: {'product_id': 179,
#   'product_name': 'Penne Rigate With Spinach',
#   'aisle_id': 131,
#   'department_id': 9,
#   'prices': 13.8},
#  179: {'product_id': 180,
#   'product_name': 'Simply Beyond Black Bean Tortilla Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 3.0},
#  180: {'product_id': 181,
#   'product_name': 'Country Style Baked Beans',
#   'aisle_id': 59,
#   'department_id': 15,
#   'prices': 1.9},
#  181: {'product_id': 182,
#   'product_name': 'Acti-Fresh Body Shape Long Unscented To Go Panty Liners',
#   'aisle_id': 126,
#   'department_id': 11,
#   'prices': 5.7},
#  182: {'product_id': 183,
#   'product_name': 'Cookie Dough Performance Energy',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 4.1},
#  183: {'product_id': 184,
#   'product_name': 'Kisses Milk Chocolate Candy',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 3.2},
#  184: {'product_id': 185,
#   'product_name': 'Chicken Nugget Meal',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 2.5},
#  185: {'product_id': 186,
#   'product_name': 'Fresh Scent Dishwasher Detergent with Dawn',
#   'aisle_id': 74,
#   'department_id': 17,
#   'prices': 11.2},
#  186: {'product_id': 187,
#   'product_name': 'Wild Sardines in Marinara Sauce',
#   'aisle_id': 95,
#   'department_id': 15,
#   'prices': 13.1},
#  187: {'product_id': 188,
#   'product_name': 'Mild El Nino Salsa',
#   'aisle_id': 67,
#   'department_id': 20,
#   'prices': 3.5},
#  188: {'product_id': 189,
#   'product_name': 'Healthfull Nuts & Seeds Bread',
#   'aisle_id': 112,
#   'department_id': 3,
#   'prices': 12.5},
#  189: {'product_id': 190,
#   'product_name': 'Classic Culinary Low Sodium Vegetable Broth',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 14.7},
#  190: {'product_id': 191,
#   'product_name': 'Medium Spicy Butter Chicken Simmer Sauce',
#   'aisle_id': 9,
#   'department_id': 9,
#   'prices': 13.4},
#  191: {'product_id': 192,
#   'product_name': 'Israeli Style Gefilte Fish',
#   'aisle_id': 33,
#   'department_id': 6,
#   'prices': 7.5},
#  192: {'product_id': 193,
#   'product_name': 'fruitwater® Strawberry Kiwi Sparkling Water',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 9.3},
#  193: {'product_id': 194,
#   'product_name': 'Lamb Rib Chops',
#   'aisle_id': 122,
#   'department_id': 12,
#   'prices': 18.9},
#  194: {'product_id': 195,
#   'product_name': 'Grade A Pasteurized 2% Milkfat Lowfat Cottage Cheese with Pineapple',
#   'aisle_id': 108,
#   'department_id': 16,
#   'prices': 3.3},
#  195: {'product_id': 196,
#   'product_name': 'Soda',
#   'aisle_id': 77,
#   'department_id': 7,
#   'prices': 9.0},
#  196: {'product_id': 197,
#   'product_name': 'Cold Brew Coffee Tahitian Vanilla',
#   'aisle_id': 26,
#   'department_id': 7,
#   'prices': 7.5},
#  197: {'product_id': 198,
#   'product_name': 'Tzatziki Cucumber Sauce',
#   'aisle_id': 67,
#   'department_id': 20,
#   'prices': 9.1},
#  198: {'product_id': 199,
#   'product_name': 'Herb Thyme Clamshell',
#   'aisle_id': 16,
#   'department_id': 4,
#   'prices': 3.8},
#  199: {'product_id': 200,
#   'product_name': 'Radiant Pantiliners Regular Wrapped Unscented',
#   'aisle_id': 126,
#   'department_id': 11,
#   'prices': 4.9},
#  200: {'product_id': 201,
#   'product_name': 'Sloppy Joe',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 7.2},
#  201: {'product_id': 202,
#   'product_name': 'Spinach & Feta Pierogi',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 6.3},
#  202: {'product_id': 203,
#   'product_name': 'Rescue Remedy, Spray',
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 6.1},
#  203: {'product_id': 204,
#   'product_name': 'Free & Clear Natural Laundry Detergent For Sensitive Skin',
#   'aisle_id': 75,
#   'department_id': 17,
#   'prices': 12.3},
#  204: {'product_id': 205,
#   'product_name': 'Chocolate Mint Cookie Crunch Nutrition Bar',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 4.5},
#  205: {'product_id': 206,
#   'product_name': 'Roasted Vegetable Soufflé',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 7.9},
#  206: {'product_id': 207,
#   'product_name': 'Minis Candy Bars',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 2.5},
#  207: {'product_id': 208,
#   'product_name': 'Vanilla Almond Cashew Almondmilk Cashewmilk Blend',
#   'aisle_id': 91,
#   'department_id': 16,
#   'prices': 3.2},
#  208: {'product_id': 209,
#   'product_name': 'Italian Pasta Salad',
#   'aisle_id': 1,
#   'department_id': 20,
#   'prices': 3.6},
#  209: {'product_id': 210,
#   'product_name': 'Homemade Hot Arrabbiata Fra Diavolo Sauce',
#   'aisle_id': 9,
#   'department_id': 9,
#   'prices': 10.8},
#  210: {'product_id': 211,
#   'product_name': 'Gluten Free Organic Cereal Coconut Maple Vanilla',
#   'aisle_id': 130,
#   'department_id': 14,
#   'prices': 3.6},
#  211: {'product_id': 212,
#   'product_name': 'Organic Blue Corn Sea Salt Tortilla Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 4.4},
#  212: {'product_id': 213,
#   'product_name': 'Tapatio Salsa Picante Hot Sauce Tortilla Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 2.6},
#  213: {'product_id': 214,
#   'product_name': 'Argan Oil of Morocco Renewing Weightless Healing Dry Oil Hair Oil',
#   'aisle_id': 22,
#   'department_id': 11,
#   'prices': 9.7},
#  214: {'product_id': 215,
#   'product_name': 'Sambal Oelek Ground Fresh Chili Paste',
#   'aisle_id': 66,
#   'department_id': 6,
#   'prices': 14.1},
#  215: {'product_id': 216,
#   'product_name': 'Gluten Free Oatmeal, Variety Pack',
#   'aisle_id': 130,
#   'department_id': 14,
#   'prices': 4.5},
#  216: {'product_id': 217,
#   'product_name': 'String Cheese, Mozzarella',
#   'aisle_id': 108,
#   'department_id': 16,
#   'prices': 11.2},
#  217: {'product_id': 218,
#   'product_name': '6\\" Organic Carrot Cake',
#   'aisle_id': 8,
#   'department_id': 3,
#   'prices': 8.2},
#  218: {'product_id': 219,
#   'product_name': 'Totz Toothbrush Extra Soft 18+ Months',
#   'aisle_id': 82,
#   'department_id': 18,
#   'prices': 3.3},
#  219: {'product_id': 220,
#   'product_name': 'Tegaderm Waterproof Transparent Dressing',
#   'aisle_id': 118,
#   'department_id': 11,
#   'prices': 9.5},
#  220: {'product_id': 221,
#   'product_name': 'Cayenne Lemonade Made With Raw Tristate Honey',
#   'aisle_id': 31,
#   'department_id': 7,
#   'prices': 4.7},
#  221: {'product_id': 222,
#   'product_name': 'Honey Nut Oatmeal Squares',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 1.1},
#  222: {'product_id': 223,
#   'product_name': 'Kiwi Strawberry Sparkling Water',
#   'aisle_id': 115,
#   'department_id': 7,
#   'prices': 4.0},
#  223: {'product_id': 224,
#   'product_name': 'Foaming Hand Soap Kid Watermelon',
#   'aisle_id': 114,
#   'department_id': 17,
#   'prices': 11.2},
#  224: {'product_id': 225,
#   'product_name': '3 Seed Blue Corn Dipping Chips',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 4.0},
#  225: {'product_id': 226,
#   'product_name': 'Shaved Parmesan Cheese',
#   'aisle_id': 21,
#   'department_id': 16,
#   'prices': 5.3},
#  226: {'product_id': 227,
#   'product_name': 'Triple Chocolate Snack Size',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 6.3},
#  227: {'product_id': 228,
#   'product_name': 'Organic Soups Lentil',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 2.7},
#  228: {'product_id': 229,
#   'product_name': 'EcoNet Recycled Bath Sponge',
#   'aisle_id': 109,
#   'department_id': 11,
#   'prices': 9.5},
#  229: {'product_id': 230,
#   'product_name': 'Vanilla Cream Soda',
#   'aisle_id': 77,
#   'department_id': 7,
#   'prices': 10.0},
#  230: {'product_id': 231,
#   'product_name': 'Low Sodium Turkey',
#   'aisle_id': 49,
#   'department_id': 12,
#   'prices': 12.6},
#  231: {'product_id': 232,
#   'product_name': 'Blue Bottle Coffee Frozen Bar',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 6.9},
#  232: {'product_id': 233,
#   'product_name': 'Chinese Breakfast Black Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 8.4},
#  233: {'product_id': 234,
#   'product_name': 'Tennessee Whiskey',
#   'aisle_id': 124,
#   'department_id': 5,
#   'prices': 3.1},
#  234: {'product_id': 235,
#   'product_name': 'Gluten Free Blueberry Muffin Mix',
#   'aisle_id': 105,
#   'department_id': 13,
#   'prices': 9.9},
#  235: {'product_id': 236,
#   'product_name': 'Chicken Meatballs Dog Treats',
#   'aisle_id': 40,
#   'department_id': 8,
#   'prices': 1.0},
#  236: {'product_id': 237,
#   'product_name': 'Brambleberry Herbal Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 14.2},
#  237: {'product_id': 238,
#   'product_name': 'Alpha-Bits Multigrain Cereal',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 11.9},
#  238: {'product_id': 239,
#   'product_name': 'Chicharrones Picante Flavor Pork Rinds',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 2.1},
#  239: {'product_id': 240,
#   'product_name': "Nature's Seasons Seasoning Blend",
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 8.7},
#  240: {'product_id': 241,
#   'product_name': 'Shrimp with Pasta & Vegetables',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 8.0},
#  241: {'product_id': 242,
#   'product_name': 'Original Red Twists',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 3.7},
#  242: {'product_id': 243,
#   'product_name': 'Taco Reduced Sodium Seasoning Mix',
#   'aisle_id': 5,
#   'department_id': 13,
#   'prices': 10.2},
#  243: {'product_id': 244,
#   'product_name': 'Organic Roasted Garlic Pasta Sauce',
#   'aisle_id': 9,
#   'department_id': 9,
#   'prices': 2.0},
#  244: {'product_id': 245,
#   'product_name': 'Poppy Seed Bagels',
#   'aisle_id': 93,
#   'department_id': 3,
#   'prices': 4.4},
#  245: {'product_id': 246,
#   'product_name': 'Triple-Acting Laundry Stain Remover',
#   'aisle_id': 75,
#   'department_id': 17,
#   'prices': 3.5},
#  246: {'product_id': 247,
#   'product_name': 'Perfectly Thymed Pita Crisps Baked',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 2.3},
#  247: {'product_id': 248,
#   'product_name': 'Dried Sweetened Cranberries',
#   'aisle_id': 117,
#   'department_id': 19,
#   'prices': 2.5},
#  248: {'product_id': 249,
#   'product_name': 'Pinot Grigio, California, 2010',
#   'aisle_id': 62,
#   'department_id': 5,
#   'prices': 2.7},
#  249: {'product_id': 250,
#   'product_name': 'Authentic Deep Dish, Spinach & Garlic Pizza',
#   'aisle_id': 79,
#   'department_id': 1,
#   'prices': 9.9},
#  250: {'product_id': 251,
#   'product_name': 'Extra Strength Melatonin Adult Gummies',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 13.8},
#  251: {'product_id': 252,
#   'product_name': 'Waffles, Red Berry',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 4.9},
#  252: {'product_id': 253,
#   'product_name': 'Organic Vegetable Greens & Greens Juice Blend',
#   'aisle_id': 31,
#   'department_id': 7,
#   'prices': 4.2},
#  253: {'product_id': 254,
#   'product_name': 'Honey Mustard',
#   'aisle_id': 72,
#   'department_id': 13,
#   'prices': 13.8},
#  254: {'product_id': 255,
#   'product_name': 'Cold Remedy, Quick Dissolve Tablets, Cherry Flavor',
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 6.9},
#  255: {'product_id': 256,
#   'product_name': 'Island Fruits Fruit Snacks',
#   'aisle_id': 50,
#   'department_id': 19,
#   'prices': 2.7},
#  256: {'product_id': 257,
#   'product_name': 'Key Lime Soda',
#   'aisle_id': 77,
#   'department_id': 7,
#   'prices': 2.5},
#  257: {'product_id': 258,
#   'product_name': 'Vegetable Pot Pie',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 8.3},
#  258: {'product_id': 259,
#   'product_name': 'Imported Italian Solid Light Tuna In Pure Olive Oil',
#   'aisle_id': 95,
#   'department_id': 15,
#   'prices': 13.8},
#  259: {'product_id': 260,
#   'product_name': 'Cantaloupe',
#   'aisle_id': 24,
#   'department_id': 4,
#   'prices': 1.4},
#  260: {'product_id': 261,
#   'product_name': 'Organic Southwestern Burrito',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 13.1},
#  261: {'product_id': 262,
#   'product_name': nan,
#   'aisle_id': 110,
#   'department_id': 13,
#   'prices': 12.1},
#  262: {'product_id': 263,
#   'product_name': 'Red Food Color',
#   'aisle_id': 97,
#   'department_id': 13,
#   'prices': 10.0},
#  263: {'product_id': 264,
#   'product_name': 'Non-Fat Blueberry on the Bottom Greek Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 1.6},
#  264: {'product_id': 265,
#   'product_name': 'Glass Storage Container with Green Silicone Protection',
#   'aisle_id': 85,
#   'department_id': 17,
#   'prices': 5.8},
#  265: {'product_id': 266,
#   'product_name': 'Rio Berry',
#   'aisle_id': 64,
#   'department_id': 7,
#   'prices': 2.6},
#  266: {'product_id': 267,
#   'product_name': 'Triple Chocolate Ripple',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 12.7},
#  267: {'product_id': 268,
#   'product_name': 'Sponge Mop',
#   'aisle_id': 114,
#   'department_id': 17,
#   'prices': 4.2},
#  268: {'product_id': 269,
#   'product_name': 'Stuffed Crust Five Cheese Pizza',
#   'aisle_id': 79,
#   'department_id': 1,
#   'prices': 6.3},
#  269: {'product_id': 270,
#   'product_name': 'OneZip Storage Bags Quart Size Value Pack',
#   'aisle_id': 85,
#   'department_id': 17,
#   'prices': 1.3},
#  270: {'product_id': 271,
#   'product_name': 'TAI PEI      14OZ.SWEET & SOUR CHKN',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 7.8},
#  271: {'product_id': 272,
#   'product_name': 'Propolis Herbal Supplement',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 6.5},
#  272: {'product_id': 273,
#   'product_name': 'Thin Stackers Brown Rice  Salt Free',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 6.3},
#  273: {'product_id': 274,
#   'product_name': 'Snack Bags',
#   'aisle_id': 87,
#   'department_id': 17,
#   'prices': 14.8},
#  274: {'product_id': 275,
#   'product_name': 'Caramel Sauce',
#   'aisle_id': 103,
#   'department_id': 19,
#   'prices': 3.0},
#  275: {'product_id': 276,
#   'product_name': 'French Vanilla Ice Cream',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 5.4},
#  276: {'product_id': 277,
#   'product_name': 'Diet Root Beer',
#   'aisle_id': 77,
#   'department_id': 7,
#   'prices': 5.4},
#  277: {'product_id': 278,
#   'product_name': 'Instant Mashed Potatoes',
#   'aisle_id': 4,
#   'department_id': 9,
#   'prices': 3.5},
#  278: {'product_id': 279,
#   'product_name': 'Everyday Detox Dandelion Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 2.2},
#  279: {'product_id': 280,
#   'product_name': 'Makeup Remover Cleansing Towelettes',
#   'aisle_id': 73,
#   'department_id': 11,
#   'prices': 8.5},
#  280: {'product_id': 281,
#   'product_name': 'Chai Tea Bags',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 6.2},
#  281: {'product_id': 282,
#   'product_name': 'Oh My Cod! Cod Pate and Vegetables Cat Food',
#   'aisle_id': 40,
#   'department_id': 8,
#   'prices': 12.5},
#  282: {'product_id': 283,
#   'product_name': 'Organic Whole Wheat Elbows',
#   'aisle_id': 131,
#   'department_id': 9,
#   'prices': 1.4},
#  283: {'product_id': 284,
#   'product_name': 'Organic Spicy Heirloom Marinara Sauce',
#   'aisle_id': 9,
#   'department_id': 9,
#   'prices': 13.0},
#  284: {'product_id': 285,
#   'product_name': 'Mini Nilla Wafers Munch Pack',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 5.9},
#  285: {'product_id': 286,
#   'product_name': 'Lite Poppy Seed Dressing Lite',
#   'aisle_id': 89,
#   'department_id': 13,
#   'prices': 1.7},
#  286: {'product_id': 287,
#   'product_name': 'Turkey',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 11.3},
#  287: {'product_id': 288,
#   'product_name': 'Original Sprouted Grains Protein & Fiber Hot Oatmeal',
#   'aisle_id': 130,
#   'department_id': 14,
#   'prices': 4.5},
#  288: {'product_id': 289,
#   'product_name': '100% Juice No Sugar Added Fruit Punch',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 1.1},
#  289: {'product_id': 290,
#   'product_name': 'Organic Peppermint Lemonade',
#   'aisle_id': 31,
#   'department_id': 7,
#   'prices': 9.3},
#  290: {'product_id': 291,
#   'product_name': 'Mint Dental Floss',
#   'aisle_id': 20,
#   'department_id': 11,
#   'prices': 14.6},
#  291: {'product_id': 292,
#   'product_name': 'Fresh Multi-Purpose Contact Lens Solution',
#   'aisle_id': 44,
#   'department_id': 11,
#   'prices': 13.0},
#  292: {'product_id': 293,
#   'product_name': 'Prime Filets Chicken & Tuna Dinner in Gravy Cat Food',
#   'aisle_id': 41,
#   'department_id': 8,
#   'prices': 13.4},
#  293: {'product_id': 294,
#   'product_name': 'Minis Original Saltine Crackers',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 4.9},
#  294: {'product_id': 295,
#   'product_name': 'Chewables Extra Strength Cherry Creme - 48 CT',
#   'aisle_id': 70,
#   'department_id': 11,
#   'prices': 4.5},
#  295: {'product_id': 296,
#   'product_name': 'For Men Odor Armor Body Wash',
#   'aisle_id': 127,
#   'department_id': 11,
#   'prices': 12.2},
#  296: {'product_id': 297,
#   'product_name': 'Write Bros Ball Point Pens, Cap-Pen, Medium (1.0 mm), Black Ink',
#   'aisle_id': 100,
#   'department_id': 21,
#   'prices': 8.8},
#  297: {'product_id': 298,
#   'product_name': 'Brisk With Lemon Iced Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 1.4},
#  298: {'product_id': 299,
#   'product_name': 'Organic Apple Spinach Kale Coconut Water Superjuice',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 12.7},
#  299: {'product_id': 300,
#   'product_name': 'Organic Enriched Unbleached White Flour',
#   'aisle_id': 17,
#   'department_id': 13,
#   'prices': 3.7},
#  300: {'product_id': 301,
#   'product_name': 'Biotin 10,000mcg Maximum Strength',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 13.9},
#  301: {'product_id': 302,
#   'product_name': 'Gourmet Dog Treats Bone',
#   'aisle_id': 40,
#   'department_id': 8,
#   'prices': 9.3},
#  302: {'product_id': 303,
#   'product_name': 'Candy, Original',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 4.3},
#  303: {'product_id': 304,
#   'product_name': 'Dry Roasted Pistachios',
#   'aisle_id': 117,
#   'department_id': 19,
#   'prices': 4.6},
#  304: {'product_id': 305,
#   'product_name': 'Wild Forest Raw Neem Honey',
#   'aisle_id': 29,
#   'department_id': 13,
#   'prices': 20.0},
#  305: {'product_id': 306,
#   'product_name': 'Gold Potatoes',
#   'aisle_id': 83,
#   'department_id': 4,
#   'prices': 2.3},
#  306: {'product_id': 307,
#   'product_name': 'Precious Mozzarella Cheese',
#   'aisle_id': 21,
#   'department_id': 16,
#   'prices': 12.2},
#  307: {'product_id': 308,
#   'product_name': 'Advanced Haircare Color Vibrancy Nourishing Shampoo',
#   'aisle_id': 22,
#   'department_id': 11,
#   'prices': 14.5},
#  308: {'product_id': 309,
#   'product_name': "Graduates Lil' Entrees Spiral Pasta In Turkey Meat Sauce With Green & Yellow Beans",
#   'aisle_id': 92,
#   'department_id': 18,
#   'prices': 14.9},
#  309: {'product_id': 310,
#   'product_name': 'Crackers, Puffed, Corn, Quinoa & Sesame',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 5.3},
#  310: {'product_id': 311,
#   'product_name': 'Naturals Savory Turkey Breakfast Sausage',
#   'aisle_id': 52,
#   'department_id': 1,
#   'prices': 3.5},
#  311: {'product_id': 312,
#   'product_name': 'Juicing Carrots',
#   'aisle_id': 83,
#   'department_id': 4,
#   'prices': 2.9},
#  312: {'product_id': 313,
#   'product_name': 'Peppermint/Banana Split Variety Pack Frozen Dairy Dessert Cones',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 14.9},
#  313: {'product_id': 314,
#   'product_name': 'Extra Whitening Multi-Benefit Fluoride Toothpaste',
#   'aisle_id': 20,
#   'department_id': 11,
#   'prices': 3.3},
#  314: {'product_id': 315,
#   'product_name': 'Creamy Italian Dressing Marinade',
#   'aisle_id': 89,
#   'department_id': 13,
#   'prices': 1.4},
#  315: {'product_id': 316,
#   'product_name': 'Revive Anti-Perspirant Deodorant',
#   'aisle_id': 80,
#   'department_id': 11,
#   'prices': 14.9},
#  316: {'product_id': 317,
#   'product_name': 'Best Grains Honey & Crunch Oat Bread',
#   'aisle_id': 112,
#   'department_id': 3,
#   'prices': 14.8},
#  317: {'product_id': 318,
#   'product_name': 'Apple Cinnamon Crisp Candle',
#   'aisle_id': 101,
#   'department_id': 17,
#   'prices': 6.4},
#  318: {'product_id': 319,
#   'product_name': "Steamfresh Chef's Favorites Lightly Sauced Roasted Red Potatoes & Green Beans",
#   'aisle_id': 116,
#   'department_id': 1,
#   'prices': 2.6},
#  319: {'product_id': 320,
#   'product_name': 'Glycerine Soap, Pure and Natural, Cucumber',
#   'aisle_id': 25,
#   'department_id': 11,
#   'prices': 6.8},
#  320: {'product_id': 321,
#   'product_name': 'Echinacea Goldenseal Alcohol Free Extract',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 5.1},
#  321: {'product_id': 322,
#   'product_name': 'Brooklyn Pizza Dough',
#   'aisle_id': 79,
#   'department_id': 1,
#   'prices': 3.4},
#  322: {'product_id': 323,
#   'product_name': 'Natural Food Color Packets',
#   'aisle_id': 17,
#   'department_id': 13,
#   'prices': 6.8},
#  323: {'product_id': 324,
#   'product_name': 'Strong & Kind Roasted Jalapeno Almond Protein Bar',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 5.0},
#  324: {'product_id': 325,
#   'product_name': 'Veggie-Style Mini Corn Dogs',
#   'aisle_id': 42,
#   'department_id': 1,
#   'prices': 9.4},
#  325: {'product_id': 326,
#   'product_name': 'Deluxe Sauce Made with 2% Milk Cheese Macaroni & Cheese Dinner',
#   'aisle_id': 4,
#   'department_id': 9,
#   'prices': 5.7},
#  326: {'product_id': 327,
#   'product_name': 'Green Peas, Organic, Petite',
#   'aisle_id': 116,
#   'department_id': 1,
#   'prices': 11.5},
#  327: {'product_id': 328,
#   'product_name': 'Disinfectant Spray Cherry Blossom & Pomegranate Scent',
#   'aisle_id': 101,
#   'department_id': 17,
#   'prices': 5.5},
#  328: {'product_id': 329,
#   'product_name': 'Organic Whole Grassmilk Milk',
#   'aisle_id': 84,
#   'department_id': 16,
#   'prices': 7.5},
#  329: {'product_id': 330,
#   'product_name': 'Chilpotles in Adobo Sauce',
#   'aisle_id': 30,
#   'department_id': 6,
#   'prices': 8.5},
#  330: {'product_id': 331,
#   'product_name': 'Organic Lemon Gingersnap',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 2.5},
#  331: {'product_id': 332,
#   'product_name': 'Raspberry Fig Bars',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 5.0},
#  332: {'product_id': 333,
#   'product_name': 'Basil Daly Bar Soap',
#   'aisle_id': 25,
#   'department_id': 11,
#   'prices': 12.6},
#  333: {'product_id': 334,
#   'product_name': 'Sparkling Raspberry Lemonade Water Beverage',
#   'aisle_id': 115,
#   'department_id': 7,
#   'prices': 5.9},
#  334: {'product_id': 335,
#   'product_name': 'Blueberry Kombucha',
#   'aisle_id': 31,
#   'department_id': 7,
#   'prices': 13.7},
#  335: {'product_id': 336,
#   'product_name': 'Black Currant Kombucha',
#   'aisle_id': 31,
#   'department_id': 7,
#   'prices': 3.5},
#  336: {'product_id': 337,
#   'product_name': 'Soap, Pure-Castile, 18-in-1 Hemp, Lavender',
#   'aisle_id': 25,
#   'department_id': 11,
#   'prices': 2.0},
#  337: {'product_id': 338,
#   'product_name': 'Yahrzeit Light Memorial Candle',
#   'aisle_id': 33,
#   'department_id': 6,
#   'prices': 2.3},
#  338: {'product_id': 339,
#   'product_name': 'Creamline Yogurt Wild Blueberry',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 11.2},
#  339: {'product_id': 340,
#   'product_name': 'Eco-Pac Kamut Puffs Cereal',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 7.8},
#  340: {'product_id': 341,
#   'product_name': 'Cheese Creations Four Cheese Cheese Sauce',
#   'aisle_id': 9,
#   'department_id': 9,
#   'prices': 1.9},
#  341: {'product_id': 342,
#   'product_name': 'Complete Health Deboned Chicken, Chicken Meal and Rice Cat Food',
#   'aisle_id': 41,
#   'department_id': 8,
#   'prices': 7.5},
#  342: {'product_id': 343,
#   'product_name': 'Organic Whole Peeled Baby Carrots',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 9.0},
#  343: {'product_id': 344,
#   'product_name': 'Lime Sherbet',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 13.2},
#  344: {'product_id': 345,
#   'product_name': 'Extra Strength Berry',
#   'aisle_id': 64,
#   'department_id': 7,
#   'prices': 3.4},
#  345: {'product_id': 346,
#   'product_name': 'Sunflower Bread',
#   'aisle_id': 112,
#   'department_id': 3,
#   'prices': 14.5},
#  346: {'product_id': 347,
#   'product_name': 'Vegetable Salad Kit, Sweet Kale',
#   'aisle_id': 123,
#   'department_id': 4,
#   'prices': 6.3},
#  347: {'product_id': 348,
#   'product_name': 'Super Slimming Herbal Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 10.6},
#  348: {'product_id': 349,
#   'product_name': 'Organic Granulated Tapioca',
#   'aisle_id': 17,
#   'department_id': 13,
#   'prices': 8.4},
#  349: {'product_id': 350,
#   'product_name': "Mixed 12 Pack Lion's Share Ale",
# ...
#   'aisle_id': 13,
#   'department_id': 20,
#   'prices': 14.8},
#  886: {'product_id': 886,
#   'product_name': 'Whole Grain Salad with Roasted Pecans & Mango Vinaigrette',
#   'aisle_id': 1,
#   'department_id': 20,
#   'prices': 1.8},
#  887: {'product_id': 887,
#   'product_name': 'Creamy Supreme Buttercream Frosting',
#   'aisle_id': 97,
#   'department_id': 13,
#   'prices': 3.2},
#  888: {'product_id': 888,
#   'product_name': 'Clean Freak Refreshing Dry Shampoo',
#   'aisle_id': 22,
#   'department_id': 11,
#   'prices': 2.9},
#  889: {'product_id': 889,
#   'product_name': 'Oatnut Bread',
#   'aisle_id': 112,
#   'department_id': 3,
#   'prices': 5.5},
#  890: {'product_id': 890,
#   'product_name': 'Organic Diced Tomatoes',
#   'aisle_id': 81,
#   'department_id': 15,
#   'prices': 4.9},
#  891: {'product_id': 891,
#   'product_name': 'Liquid Water Enhance Ice Van Java',
#   'aisle_id': 100,
#   'department_id': 21,
#   'prices': 7.4},
#  892: {'product_id': 892,
#   'product_name': 'White Tea Lavender Probiotic Kefir Water No. 2',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 4.0},
#  893: {'product_id': 893,
#   'product_name': 'Vitamin E Oil 45,000 IU',
#   'aisle_id': 109,
#   'department_id': 11,
#   'prices': 13.4},
#  894: {'product_id': 894,
#   'product_name': 'Greek 100 Calories Vanilla Fat Free Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 4.8},
#  895: {'product_id': 895,
#   'product_name': 'YoKids Squeeze Organic Blueberry Blue Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 8.2},
#  896: {'product_id': 896,
#   'product_name': "Children's Bubblegum Flavor Suspension",
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 1.7},
#  897: {'product_id': 897,
#   'product_name': 'Pearl Active Duopack Tampons',
#   'aisle_id': 126,
#   'department_id': 11,
#   'prices': 9.2},
#  898: {'product_id': 898,
#   'product_name': 'Saucy Ginger Mandarin Dressing',
#   'aisle_id': 89,
#   'department_id': 13,
#   'prices': 11.1},
#  899: {'product_id': 899,
#   'product_name': 'Colby Jack Cheese Slices',
#   'aisle_id': 21,
#   'department_id': 16,
#   'prices': 8.8},
#  900: {'product_id': 900,
#   'product_name': 'Fava Crisps, Santa Barbara Ranch',
#   'aisle_id': 107,
#   'department_id': 19,
#   'prices': 1.7},
#  901: {'product_id': 901,
#   'product_name': 'Dark Chocolate Peanut Candy',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 4.8},
#  902: {'product_id': 902,
#   'product_name': 'Baked Rice Crisps, Sour Cream & Wasabi, Medium',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 2.7},
#  903: {'product_id': 903,
#   'product_name': 'Gluten Free Sugar Cones',
#   'aisle_id': 103,
#   'department_id': 19,
#   'prices': 5.0},
#  904: {'product_id': 904,
#   'product_name': 'Tofu, Gluten Free, Garlic Pepper',
#   'aisle_id': 14,
#   'department_id': 20,
#   'prices': 10.2},
#  905: {'product_id': 905,
#   'product_name': 'Fish Oil with Vitamin D 1000mg',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 12.7},
#  906: {'product_id': 906,
#   'product_name': 'Chamomilla 30 C',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 14.2},
#  907: {'product_id': 907,
#   'product_name': 'Premium Sliced Bacon',
#   'aisle_id': 106,
#   'department_id': 12,
#   'prices': 20.0},
#  908: {'product_id': 908,
#   'product_name': 'Onion & Herb Salt-Free Seasoning Blend',
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 9.5},
#  909: {'product_id': 909,
#   'product_name': 'Calcium Magnesium Citrate Plus Vitamin D3 Natural Mixed Berry Flavor',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 1.5},
#  910: {'product_id': 910,
#   'product_name': 'Nutri-Grain Harvest Hearty Breakfast Bars Country Strawberry',
#   'aisle_id': 48,
#   'department_id': 14,
#   'prices': 5.8},
#  911: {'product_id': 911,
#   'product_name': 'Protein Shake, Organic, Banana Creme',
#   'aisle_id': 64,
#   'department_id': 7,
#   'prices': 8.9},
#  912: {'product_id': 912,
#   'product_name': 'Mushroom Stems & Pieces in Water',
#   'aisle_id': 81,
#   'department_id': 15,
#   'prices': 14.9},
#  913: {'product_id': 913,
#   'product_name': 'Dry Pasta Lasagne',
#   'aisle_id': 131,
#   'department_id': 9,
#   'prices': 14.6},
#  914: {'product_id': 914,
#   'product_name': 'Cold & Cough Formula, Effervescent Tablets, Citrus',
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 13.0},
#  915: {'product_id': 915,
#   'product_name': 'Ultra Soft & Strong Double Roll Bath Tissue',
#   'aisle_id': 54,
#   'department_id': 17,
#   'prices': 13.6},
#  916: {'product_id': 916,
#   'product_name': 'Majestic Roast Ground Coffee',
#   'aisle_id': 26,
#   'department_id': 7,
#   'prices': 4.7},
#  917: {'product_id': 917,
#   'product_name': "All Time Great's Candy Assortment",
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 2.2},
#  918: {'product_id': 918,
#   'product_name': 'Light Brie Soft-Ripened Cheese Mini-Wheel',
#   'aisle_id': 2,
#   'department_id': 16,
#   'prices': 10.4},
#  919: {'product_id': 919,
#   'product_name': 'Apricot Fruit Roll',
#   'aisle_id': 50,
#   'department_id': 19,
#   'prices': 5.3},
#  920: {'product_id': 920,
#   'product_name': 'Coconut Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 1.1},
#  921: {'product_id': 921,
#   'product_name': 'Black Salt Caramel Dark Chocolate Bar',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 5.6},
#  922: {'product_id': 922,
#   'product_name': 'Chipotle & Roasted Garlic Seasoning',
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 2.2},
#  923: {'product_id': 923,
#   'product_name': 'Country Fresh Old Fashioned Horseradish',
#   'aisle_id': 88,
#   'department_id': 13,
#   'prices': 8.1},
#  924: {'product_id': 924,
#   'product_name': '2 In 1 Laundry Detergent',
#   'aisle_id': 75,
#   'department_id': 17,
#   'prices': 2.4},
#  925: {'product_id': 925,
#   'product_name': 'Southern Style Diced Hash Brown Potatoes',
#   'aisle_id': 129,
#   'department_id': 1,
#   'prices': 3.1},
#  926: {'product_id': 926,
#   'product_name': 'Crispy Thin Crust White Pizza',
#   'aisle_id': 79,
#   'department_id': 1,
#   'prices': 1.2},
#  927: {'product_id': 927,
#   'product_name': 'Cabernet Sauvignon, Central Coast, 2011',
#   'aisle_id': 28,
#   'department_id': 5,
#   'prices': 9.8},
#  928: {'product_id': 928,
#   'product_name': 'Chunky Classic Chicken Noodle Soup',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 11.0},
#  929: {'product_id': 929,
#   'product_name': 'New England Clam Chowder Condensed Soup',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 3.5},
#  930: {'product_id': 930,
#   'product_name': 'ULTRACLEAN™ Cool Mint ULTRACLEAN™',
#   'aisle_id': 20,
#   'department_id': 11,
#   'prices': 8.6},
#  931: {'product_id': 931,
#   'product_name': 'Lash Discovery Waterproof Mascara - Very Black',
#   'aisle_id': 132,
#   'department_id': 11,
#   'prices': 1.2},
#  932: {'product_id': 932,
#   'product_name': 'Vegetable Pie In A Pocket Sandwich',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 10.4},
#  933: {'product_id': 933,
#   'product_name': "Roarin' Waters Wild Cherry Water Beverage",
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 10.7},
#  934: {'product_id': 934,
#   'product_name': 'Mini Pre-Sliced Blueberry Bagels',
#   'aisle_id': 93,
#   'department_id': 3,
#   'prices': 4.4},
#  935: {'product_id': 935,
#   'product_name': 'Premium Apple Juice',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 3.1},
#  936: {'product_id': 936,
#   'product_name': 'Butterfinger Smooth & Crunchy Peanut Butter Cups',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 4.1},
#  937: {'product_id': 937,
#   'product_name': 'Buffalo Style Chicken Strips',
#   'aisle_id': 129,
#   'department_id': 1,
#   'prices': 9.6},
#  938: {'product_id': 938,
#   'product_name': 'Disinfectant Spray, Crisp Linen Scent',
#   'aisle_id': 114,
#   'department_id': 17,
#   'prices': 1.6},
#  939: {'product_id': 939,
#   'product_name': "Annie's Bunny Fruit Snacks Variety",
#   'aisle_id': 50,
#   'department_id': 19,
#   'prices': 2.5},
#  940: {'product_id': 940,
#   'product_name': 'Bathroom Tissue',
#   'aisle_id': 54,
#   'department_id': 17,
#   'prices': 8.3},
#  941: {'product_id': 941,
#   'product_name': 'Smoked Atlantic Nova Salmon',
#   'aisle_id': 15,
#   'department_id': 12,
#   'prices': 8.9},
#  942: {'product_id': 942,
#   'product_name': 'Echinacea & Elderberry Organic Herbal Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 14.7},
#  943: {'product_id': 943,
#   'product_name': 'Magnesium Citrate Caplets',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 10.4},
#  944: {'product_id': 944,
#   'product_name': 'Vanilla Orange Swirl Ice Cream',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 13.5},
#  945: {'product_id': 945,
#   'product_name': 'Fruit Punch Juice Drink',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 2.5},
#  946: {'product_id': 946,
#   'product_name': 'Seasonal Oikos Greek Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 13.9},
#  947: {'product_id': 947,
#   'product_name': 'Cracker Crunchers Bologna with Nestle Butterfinger Bar LunchMakers',
#   'aisle_id': 13,
#   'department_id': 20,
#   'prices': 9.1},
#  948: {'product_id': 948,
#   'product_name': 'Superior Spot & Film Protection Jet-Dry Dishwasher Rinse Aid',
#   'aisle_id': 74,
#   'department_id': 17,
#   'prices': 2.8},
#  949: {'product_id': 949,
#   'product_name': 'Sensitive Shave Gel with Aloe',
#   'aisle_id': 55,
#   'department_id': 11,
#   'prices': 12.7},
#  950: {'product_id': 950,
#   'product_name': 'Toll House Ultimate Chocolate Peanut Butter Deluxe Cookie Dough',
#   'aisle_id': 105,
#   'department_id': 13,
#   'prices': 7.9},
#  951: {'product_id': 951,
#   'product_name': 'Vitamin D3 Cholecalciferol Softgels',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 2.4},
#  952: {'product_id': 952,
#   'product_name': 'Flaxseed Meal, Whole Ground',
#   'aisle_id': 17,
#   'department_id': 13,
#   'prices': 7.7},
#  953: {'product_id': 953,
#   'product_name': 'Plain Fat Free Yogurt',
#   'aisle_id': 120,
#   'department_id': 16,
#   'prices': 14.8},
#  954: {'product_id': 954,
#   'product_name': 'Simple White Down East Crackers',
#   'aisle_id': 78,
#   'department_id': 19,
#   'prices': 3.6},
#  955: {'product_id': 955,
#   'product_name': 'Cheddar Chex Mix',
#   'aisle_id': 125,
#   'department_id': 19,
#   'prices': 3.9},
#  956: {'product_id': 956,
#   'product_name': 'Shampoo Baby Shampoo',
#   'aisle_id': 102,
#   'department_id': 18,
#   'prices': 9.0},
#  957: {'product_id': 957,
#   'product_name': 'Key Lime Moisture Shave',
#   'aisle_id': 55,
#   'department_id': 11,
#   'prices': 9.2},
#  958: {'product_id': 958,
#   'product_name': 'Almond Extract',
#   'aisle_id': 47,
#   'department_id': 11,
#   'prices': 7.2},
#  959: {'product_id': 959,
#   'product_name': 'Chicken & Vegetable Stir Fry Café Steamers',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 11.1},
#  960: {'product_id': 960,
#   'product_name': 'Villager Ipa',
#   'aisle_id': 27,
#   'department_id': 5,
#   'prices': 6.9},
#  961: {'product_id': 961,
#   'product_name': 'Grape Sunflower Butter Sunwiches',
#   'aisle_id': 13,
#   'department_id': 20,
#   'prices': 8.2},
#  962: {'product_id': 962,
#   'product_name': 'Organic Roasted Garlic Vinaigrette Dressing Organic',
#   'aisle_id': 89,
#   'department_id': 13,
#   'prices': 12.4},
#  963: {'product_id': 963,
#   'product_name': 'Unsalted Beef Broth',
#   'aisle_id': 69,
#   'department_id': 15,
#   'prices': 11.1},
#  964: {'product_id': 964,
#   'product_name': 'Toothpicks',
#   'aisle_id': 87,
#   'department_id': 17,
#   'prices': 14.2},
#  965: {'product_id': 965,
#   'product_name': 'Maxtra Cartridge Water Filter Refills',
#   'aisle_id': 87,
#   'department_id': 17,
#   'prices': 1.4},
#  966: {'product_id': 966,
#   'product_name': 'Pear Hard Cider',
#   'aisle_id': 27,
#   'department_id': 5,
#   'prices': 2.6},
#  967: {'product_id': 967,
#   'product_name': 'Gluten Free Soft & Chewy Snicker Doodle Cookies',
#   'aisle_id': 8,
#   'department_id': 3,
#   'prices': 2.4},
#  968: {'product_id': 968,
#   'product_name': 'Zipper Bags Sandwich - 50 CT',
#   'aisle_id': 85,
#   'department_id': 17,
#   'prices': 4.6},
#  969: {'product_id': 969,
#   'product_name': 'Petite Green Peas',
#   'aisle_id': 116,
#   'department_id': 1,
#   'prices': 4.8},
#  970: {'product_id': 970,
#   'product_name': 'Salmon and Tuna Formula Dry Cat Food',
#   'aisle_id': 41,
#   'department_id': 8,
#   'prices': 9.9},
#  971: {'product_id': 971,
#   'product_name': 'Chicken Alfredo with Rotini',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 7.8},
#  972: {'product_id': 972,
#   'product_name': 'Linguine No 7 Pasta',
#   'aisle_id': 131,
#   'department_id': 9,
#   'prices': 4.5},
#  973: {'product_id': 973,
#   'product_name': '8 X 6 Cutting Board',
#   'aisle_id': 10,
#   'department_id': 17,
#   'prices': 5.0},
#  974: {'product_id': 974,
#   'product_name': 'Organic 54% Cocoa Dark Chocolate Bar',
#   'aisle_id': 45,
#   'department_id': 19,
#   'prices': 4.4},
#  975: {'product_id': 975,
#   'product_name': 'Creamy Vanilla Soy Milk Frozen Dessert',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 3.9},
#  976: {'product_id': 976,
#   'product_name': 'Cavity Protection Regular Flavor Toothpaste',
#   'aisle_id': 20,
#   'department_id': 11,
#   'prices': 14.6},
#  977: {'product_id': 977,
#   'product_name': 'Deli Spicy Brown Mustard',
#   'aisle_id': 72,
#   'department_id': 13,
#   'prices': 13.7},
#  978: {'product_id': 978,
#   'product_name': 'Mallow Oats Cereals',
#   'aisle_id': 121,
#   'department_id': 14,
#   'prices': 4.4},
#  979: {'product_id': 979,
#   'product_name': 'Odor Control Home Trash Compactor Bags 18 Gallon',
#   'aisle_id': 60,
#   'department_id': 17,
#   'prices': 5.7},
#  980: {'product_id': 980,
#   'product_name': 'Automatic Toilet Bowl Cleaner with Bleach',
#   'aisle_id': 114,
#   'department_id': 17,
#   'prices': 8.7},
#  981: {'product_id': 981,
#   'product_name': 'Garlic Naan',
#   'aisle_id': 128,
#   'department_id': 3,
#   'prices': 3.8},
#  982: {'product_id': 982,
#   'product_name': 'Aged Gouda Cheese',
#   'aisle_id': 2,
#   'department_id': 16,
#   'prices': 14.1},
#  983: {'product_id': 983,
#   'product_name': 'Strawberry Pomegranate',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 3.0},
#  984: {'product_id': 984,
#   'product_name': 'Cucumber Witch Hazel With Aloe Vera',
#   'aisle_id': 109,
#   'department_id': 11,
#   'prices': 8.4},
#  985: {'product_id': 985,
#   'product_name': 'Peanut Butter Bars',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 6.4},
#  986: {'product_id': 986,
#   'product_name': 'Crushed Pineapple in 100% Juice',
#   'aisle_id': 99,
#   'department_id': 15,
#   'prices': 13.1},
#  987: {'product_id': 987,
#   'product_name': 'Naturals Antiseptic Adult Mouthwash Herbal Mint',
#   'aisle_id': 20,
#   'department_id': 11,
#   'prices': 9.4},
#  988: {'product_id': 988,
#   'product_name': 'Cranberrry  Almond Soft & Chewy Granola Bar',
#   'aisle_id': 3,
#   'department_id': 19,
#   'prices': 6.3},
#  989: {'product_id': 989,
#   'product_name': 'Chapatti Chicken Tikki Masala Wrap',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 12.6},
#  990: {'product_id': 990,
#   'product_name': 'Diced Pancetta',
#   'aisle_id': 96,
#   'department_id': 20,
#   'prices': 13.6},
#  991: {'product_id': 991,
#   'product_name': 'Red Sweet Mini Pepper',
#   'aisle_id': 100,
#   'department_id': 21,
#   'prices': 5.4},
#  992: {'product_id': 992,
#   'product_name': 'Thin Crust Pepperoni & Pesto Pizza',
#   'aisle_id': 79,
#   'department_id': 1,
#   'prices': 10.2},
#  993: {'product_id': 993,
#   'product_name': 'Mild Diced Tomatoes with Green Chilis',
#   'aisle_id': 81,
#   'department_id': 15,
#   'prices': 10.2},
#  994: {'product_id': 994,
#   'product_name': 'Shake n Pour Buttermilk Pancake Mix',
#   'aisle_id': 130,
#   'department_id': 14,
#   'prices': 13.4},
#  995: {'product_id': 995,
#   'product_name': 'Sausage Smoked Sweet German Brand',
#   'aisle_id': 106,
#   'department_id': 12,
#   'prices': 16.7},
#  996: {'product_id': 996,
#   'product_name': 'Honey Cinnamon Nut-Thins  Crackers',
#   'aisle_id': 125,
#   'department_id': 19,
#   'prices': 3.2},
#  997: {'product_id': 997,
#   'product_name': 'Mini Double Chocolate Ice Cream Bars',
#   'aisle_id': 37,
#   'department_id': 1,
#   'prices': 8.5},
#  998: {'product_id': 998,
#   'product_name': 'Hot Chopped Green Chili',
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 9.1},
#  999: {'product_id': 999,
#   'product_name': 'Original Organic Ville BBQ Sauce',
#   'aisle_id': 5,
#   'department_id': 13,
#   'prices': 9.2},
#  ...}

# %% [markdown]
# Value of 4: {'product_id': 5,
#   'product_name': 'Green Chile Anytime Sauce',
#   'aisle_id': 5,
#   'department_id': 13,
#   'prices': 4.3},

# %% [markdown]
# #The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.

# %%
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# 67          130             14    13.7
# 89          121             14     3.9
# 210         130             14     3.6
# ...         ...            ...     ...
# 49330       121             14     9.1
# 49395       130             14     2.0
# 49547       121             14    10.8
# 49637       130             14    14.2
# 49667        57             14    10.2
#
# [1116 rows x 5 columns]

# %% [markdown]
# #They’d also like to see details about products that customers might use to throw dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

# %%
df_dinner = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# 2                  7     4.5
# 6                  7     4.4
# 9                  7     8.4
# 10                 7     2.8
# 16                12    17.1
# ...              ...     ...
# 49676              7     6.5
# 49679              7    14.0
# 49680              7    14.5
# 49686              7     4.3
# 49688              5     5.3
#
# [7650 rows x 5 columns]

# %% [markdown]
# #It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

# %% [markdown]
# 7650 rows × 5 columns

# %% [markdown]
# #Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
df_ords_user1 = df_ords[df_ords['user_id']=='1']

# %%
df_ords_user1
# Out:
#     order_id user_id eval_set  order_number  order_day_of_week  \
# 0    2539329       1    prior             1                  2
# 1    2398795       1    prior             2                  3
# 2     473747       1    prior             3                  3
# 3    2254736       1    prior             4                  4
# 4     431534       1    prior             5                  4
# 5    3367565       1    prior             6                  2
# 6     550135       1    prior             7                  1
# 7    3108588       1    prior             8                  1
# 8    2295261       1    prior             9                  1
# 9    2550362       1    prior            10                  4
# 10   1187899       1    train            11                  4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# 3                   7                    29.0
# 4                  15                    28.0
# 5                   7                    19.0
# 6                   9                    20.0
# 7                  14                    14.0
# 8                  16                     0.0
# 9                   8                    30.0
# 10                  8                    14.0

# %% [markdown]
# #You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %%
df_ords_user1.describe()
# Out:
#            order_id  order_number  order_day_of_week  order_hour_of_day  \
# count  1.100000e+01     11.000000          11.000000          11.000000
# mean   1.923450e+06      6.000000           2.636364          10.090909
# std    1.071950e+06      3.316625           1.286291           3.477198
# min    4.315340e+05      1.000000           1.000000           7.000000
# 25%    8.690170e+05      3.500000           1.500000           7.500000
# 50%    2.295261e+06      6.000000           3.000000           8.000000
# 75%    2.544846e+06      8.500000           4.000000          13.000000
# max    3.367565e+06     11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# #Export orders wrangled

# %%
path = r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Prepared Data'

# %%
path
# Out:
# '/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Prepared Data'

# %%
df_ords.to_csv(r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Prepared Data/orders_wrangled.csv')
