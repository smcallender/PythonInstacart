# %% [markdown]
# Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#import dataframe 
df_ords_merged = pd.read_pickle(r'/Users/samuelcallender/Documents/ Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_updated.pkl')

# %%
#create a subset
df = df_ords_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
# 5             5           5   3367565        1    prior             6
# 6             6           6    550135        1    prior             7
# 7             7           7   3108588        1    prior             8
# 8             8           8   2295261        1    prior             9
# 9             9           9   2550362        1    prior            10
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                  2                  8                     NaN         196
# 1                  3                  7                    15.0         196
# 2                  3                 12                    21.0         196
# 3                  4                  7                    29.0         196
# 4                  4                 15                    28.0         196
# 5                  2                  7                    19.0         196
# 6                  1                  9                    20.0         196
# 7                  1                 14                    14.0         196
# 8                  1                 16                     0.0         196
# 9                  4                  8                    30.0         196
#
#    ...  reordered  product_name aisle_id  department_id  prices  _merge  \
# 0  ...          0          Soda       77              7     9.0    both
# 1  ...          1          Soda       77              7     9.0    both
# 2  ...          1          Soda       77              7     9.0    both
# 3  ...          1          Soda       77              7     9.0    both
# 4  ...          1          Soda       77              7     9.0    both
# 5  ...          1          Soda       77              7     9.0    both
# 6  ...          1          Soda       77              7     9.0    both
# 7  ...          1          Soda       77              7     9.0    both
# 8  ...          1          Soda       77              7     9.0    both
# 9  ...          1          Soda       77              7     9.0    both
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly days        Average orders
# 1  Mid-range product  Regularly busy    Slowest days        Average orders
# 2  Mid-range product  Regularly busy    Slowest days           Most orders
# 3  Mid-range product      Least busy    Slowest days        Average orders
# 4  Mid-range product      Least busy    Slowest days           Most orders
# 5  Mid-range product  Regularly busy  Regularly days        Average orders
# 6  Mid-range product  Regularly busy    Busiest days        Average orders
# 7  Mid-range product  Regularly busy    Busiest days           Most orders
# 8  Mid-range product  Regularly busy    Busiest days        Average orders
# 9  Mid-range product      Least busy    Slowest days        Average orders
#
# [10 rows x 21 columns]

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
df_ords_merged['max_order'] = df_ords_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_merged.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0              0           0   2539329        1    prior             1
# 1              1           1   2398795        1    prior             2
# 2              2           2    473747        1    prior             3
# 3              3           3   2254736        1    prior             4
# 4              4           4    431534        1    prior             5
# 5              5           5   3367565        1    prior             6
# 6              6           6    550135        1    prior             7
# 7              7           7   3108588        1    prior             8
# 8              8           8   2295261        1    prior             9
# 9              9           9   2550362        1    prior            10
# 10           144         144   2968173       15    prior            15
# 11           146         146   1870022       15    prior            17
# 12           147         147   1911383       15    prior            18
# 13           150         150   2715276       15    prior            21
# 14           151         151    487368       15    prior            22
#
#     order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
# 5                   2                  7                    19.0         196
# 6                   1                  9                    20.0         196
# 7                   1                 14                    14.0         196
# 8                   1                 16                     0.0         196
# 9                   4                  8                    30.0         196
# 10                  1                  9                     7.0         196
# 11                  2                 16                     8.0         196
# 12                  2                 11                     7.0         196
# 13                  1                  9                     7.0         196
# 14                  1                 10                    14.0         196
#
#     ...  product_name  aisle_id department_id  prices  _merge  \
# 0   ...          Soda        77             7     9.0    both
# 1   ...          Soda        77             7     9.0    both
# 2   ...          Soda        77             7     9.0    both
# 3   ...          Soda        77             7     9.0    both
# 4   ...          Soda        77             7     9.0    both
# 5   ...          Soda        77             7     9.0    both
# 6   ...          Soda        77             7     9.0    both
# 7   ...          Soda        77             7     9.0    both
# 8   ...          Soda        77             7     9.0    both
# 9   ...          Soda        77             7     9.0    both
# 10  ...          Soda        77             7     9.0    both
# 11  ...          Soda        77             7     9.0    both
# 12  ...          Soda        77             7     9.0    both
# 13  ...          Soda        77             7     9.0    both
# 14  ...          Soda        77             7     9.0    both
#
#       price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly days        Average orders
# 1   Mid-range product  Regularly busy    Slowest days        Average orders
# 2   Mid-range product  Regularly busy    Slowest days           Most orders
# 3   Mid-range product      Least busy    Slowest days        Average orders
# 4   Mid-range product      Least busy    Slowest days           Most orders
# 5   Mid-range product  Regularly busy  Regularly days        Average orders
# 6   Mid-range product  Regularly busy    Busiest days        Average orders
# 7   Mid-range product  Regularly busy    Busiest days           Most orders
# 8   Mid-range product  Regularly busy    Busiest days        Average orders
# 9   Mid-range product      Least busy    Slowest days        Average orders
# 10  Mid-range product  Regularly busy    Busiest days        Average orders
# 11  Mid-range product  Regularly busy  Regularly days        Average orders
# 12  Mid-range product  Regularly busy  Regularly days           Most orders
# 13  Mid-range product  Regularly busy    Busiest days        Average orders
# 14  Mid-range product  Regularly busy    Busiest days           Most orders
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10
# 5         10
# 6         10
# 7         10
# 8         10
# 9         10
# 10        22
# 11        22
# 12        22
# 13        22
# 14        22
#
# [15 rows x 22 columns]

# %%
df_ords_merged.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0              0           0   2539329        1    prior             1
# 1              1           1   2398795        1    prior             2
# 2              2           2    473747        1    prior             3
# 3              3           3   2254736        1    prior             4
# 4              4           4    431534        1    prior             5
# ..           ...         ...       ...      ...      ...           ...
# 95          5895        5895   3226575      360    prior             1
# 96          6137        6137   1469869      377    prior             3
# 97          6259        6259   1927023      387    prior             2
# 98          6740        6740    858092      420    prior             4
# 99          6741        6741    119314      420    prior             5
#
#     order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
# ..                ...                ...                     ...         ...
# 95                  5                 12                     NaN         196
# 96                  5                 17                     3.0         196
# 97                  4                 10                    22.0         196
# 98                  1                 19                    30.0         196
# 99                  3                 19                    16.0         196
#
#     ...  product_name  aisle_id department_id  prices  _merge  \
# 0   ...          Soda        77             7     9.0    both
# 1   ...          Soda        77             7     9.0    both
# 2   ...          Soda        77             7     9.0    both
# 3   ...          Soda        77             7     9.0    both
# 4   ...          Soda        77             7     9.0    both
# ..  ...           ...       ...           ...     ...     ...
# 95  ...          Soda        77             7     9.0    both
# 96  ...          Soda        77             7     9.0    both
# 97  ...          Soda        77             7     9.0    both
# 98  ...          Soda        77             7     9.0    both
# 99  ...          Soda        77             7     9.0    both
#
#       price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly days        Average orders
# 1   Mid-range product  Regularly busy    Slowest days        Average orders
# 2   Mid-range product  Regularly busy    Slowest days           Most orders
# 3   Mid-range product      Least busy    Slowest days        Average orders
# 4   Mid-range product      Least busy    Slowest days           Most orders
# ..                ...             ...             ...                   ...
# 95  Mid-range product  Regularly busy  Regularly days           Most orders
# 96  Mid-range product  Regularly busy  Regularly days        Average orders
# 97  Mid-range product      Least busy    Slowest days           Most orders
# 98  Mid-range product  Regularly busy    Busiest days        Average orders
# 99  Mid-range product  Regularly busy    Slowest days        Average orders
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10
# ..       ...
# 95         3
# 96         3
# 97         8
# 98        22
# 99        22
#
# [100 rows x 22 columns]

# %%
pd.options.display.max_rows = None

# %%
df_ords_merged.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0              0           0   2539329        1    prior             1
# 1              1           1   2398795        1    prior             2
# 2              2           2    473747        1    prior             3
# 3              3           3   2254736        1    prior             4
# 4              4           4    431534        1    prior             5
# 5              5           5   3367565        1    prior             6
# 6              6           6    550135        1    prior             7
# 7              7           7   3108588        1    prior             8
# 8              8           8   2295261        1    prior             9
# 9              9           9   2550362        1    prior            10
# 10           144         144   2968173       15    prior            15
# 11           146         146   1870022       15    prior            17
# 12           147         147   1911383       15    prior            18
# 13           150         150   2715276       15    prior            21
# 14           151         151    487368       15    prior            22
# 15           209         209   2293453       19    prior             2
# 16           212         212   1973799       19    prior             5
# 17           214         214    532817       19    prior             7
# 18           232         232   1573906       21    prior            10
# 19           458         458   1593000       31    prior            10
# 20           465         465   2231262       31    prior            17
# 21           617         617   2580647       43    prior             6
# 22           620         620   2187180       43    prior             9
# 23           751         751   2497897       52    prior             1
# 24           752         752   1318871       52    prior             2
# 25           753         753   1261384       52    prior             3
# 26           755         755    580568       52    prior             5
# 27           757         757   2428073       52    prior             7
# 28           759         759    342306       52    prior             9
# 29           760         760   1520353       52    prior            10
# 30           761         761   2542086       52    prior            11
# 31           762         762    944694       52    prior            12
# 32           765         765   1268191       52    prior            15
# 33           767         767   1122089       52    prior            17
# 34           768         768   1498922       52    prior            18
# 35           769         769    180919       52    prior            19
# 36           771         771   2695875       52    prior            21
# 37          1022        1022   3205960       67    prior             1
# 38          1023        1023    970922       67    prior             2
# 39          1024        1024    596585       67    prior             3
# 40          1025        1025   2037087       67    prior             4
# 41          1026        1026   2474111       67    prior             5
# 42          1027        1027   1568481       67    prior             6
# 43          1029        1029   2048527       67    prior             8
# 44          1030        1030   2389031       67    prior             9
# 45          1031        1031   2378562       67    prior            10
# 46          1032        1032   1515698       67    prior            11
# 47          1033        1033   1928050       67    prior            12
# 48          1034        1034   1949274       67    prior            13
# 49          1035        1035    551869       67    prior            14
# 50          1037        1037    768572       67    prior            16
# 51          1039        1039    150528       67    prior            18
# 52          1040        1040     29758       67    prior            19
# 53          1042        1042   1558976       67    prior            21
# 54          1043        1043    863974       67    prior            22
# 55          1044        1044   2308399       67    prior            23
# 56          1202        1202   2759128       81    prior             3
# 57          1204        1204   1812985       81    prior             5
# 58          1208        1208   1889835       82    prior             1
# 59          1210        1210    499460       82    prior             3
# 60          1211        1211   2728456       82    prior             4
# 61          1213        1213   2653743       82    prior             6
# 62          1216        1216   1358880       82    prior             9
# 63          1217        1217    343588       82    prior            10
# 64          1222        1222   3034663       82    prior            15
# 65          1225        1225    147262       82    prior            18
# 66          1226        1226   3144004       82    prior            19
# 67          1480        1480   2126069       98    prior             3
# 68          1484        1484   2210120       98    prior             7
# 69          1486        1486    681011       98    prior             9
# 70          1488        1488   2846344       98    prior            11
# 71          1489        1489    747431       98    prior            12
# 72          1490        1490   2383054       98    prior            13
# 73          1491        1491   1993729       98    prior            14
# 74          1608        1608   1403849      109    prior             3
# 75          1744        1744    520620      120    prior             1
# 76          1746        1746   3273029      120    prior             3
# 77          2781        2781   1861943      185    prior             2
# 78          2891        2891   2040988      195    prior             1
# 79          2898        2898   1680569      195    prior             8
# 80          2909        2909    276171      195    prior            19
# 81          2912        2912   2744976      195    prior            22
# 82          2915        2915   2781919      195    prior            25
# 83          2921        2921   1738718      195    prior            31
# 84          2924        2924   3058369      195    prior            34
# 85          2927        2927   1485596      195    prior            37
# 86          2930        2930    417035      195    prior            40
# 87          2937        2937   1615297      195    prior            47
# 88          2942        2942   1765587      195    prior            52
# 89          2947        2947    745908      195    prior            57
# 90          3451        3451   2505656      222    prior            17
# 91          3472        3472   3268370      222    prior            38
# 92          4667        4667   2016711      290    prior             9
# 93          4686        4686   2706088      290    prior            28
# 94          5551        5551   1952286      331    prior             6
# 95          5895        5895   3226575      360    prior             1
# 96          6137        6137   1469869      377    prior             3
# 97          6259        6259   1927023      387    prior             2
# 98          6740        6740    858092      420    prior             4
# 99          6741        6741    119314      420    prior             5
#
#     order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
# 5                   2                  7                    19.0         196
# 6                   1                  9                    20.0         196
# 7                   1                 14                    14.0         196
# 8                   1                 16                     0.0         196
# 9                   4                  8                    30.0         196
# 10                  1                  9                     7.0         196
# 11                  2                 16                     8.0         196
# 12                  2                 11                     7.0         196
# 13                  1                  9                     7.0         196
# 14                  1                 10                    14.0         196
# 15                  5                 14                     6.0         196
# 16                  6                 12                     8.0         196
# 17                  4                 17                     6.0         196
# 18                  3                 10                     6.0         196
# 19                  3                  8                     7.0         196
# 20                  3                 11                     8.0         196
# 21                  4                 16                     4.0         196
# 22                  4                 12                     3.0         196
# 23                  1                  9                     NaN         196
# 24                  1                 10                     7.0         196
# 25                  1                 10                     7.0         196
# 26                  2                 10                     8.0         196
# 27                  2                  7                     8.0         196
# 28                  1                 11                     7.0         196
# 29                  2                 10                     8.0         196
# 30                  2                  9                     7.0         196
# 31                  1                 16                     6.0         196
# 32                  2                 11                     8.0         196
# 33                  2                 10                     6.0         196
# 34                  2                 10                    14.0         196
# 35                  3                  8                     8.0         196
# 36                  5                 10                    30.0         196
# 37                  3                 11                     NaN         196
# 38                  1                 15                     5.0         196
# 39                  1                 13                     7.0         196
# 40                  2                  9                     8.0         196
# 41                  3                 14                     8.0         196
# 42                  3                 12                     7.0         196
# 43                  2                 11                     7.0         196
# 44                  2                 14                     7.0         196
# 45                  1                 10                     6.0         196
# 46                  1                 11                     7.0         196
# 47                  2                 12                     8.0         196
# 48                  1                 10                     6.0         196
# 49                  1                  9                     7.0         196
# 50                  4                 10                     9.0         196
# 51                  5                 16                     4.0         196
# 52                  0                 14                     9.0         196
# 53                  1                  9                     5.0         196
# 54                  1                 11                    14.0         196
# 55                  1                 14                    14.0         196
# 56                  1                  9                    14.0         196
# 57                  2                 20                    30.0         196
# 58                  3                 15                     NaN         196
# 59                  5                 10                     5.0         196
# 60                  0                 11                    16.0         196
# 61                  4                  9                    13.0         196
# 62                  1                 10                    30.0         196
# 63                  2                 11                     1.0         196
# 64                  2                 11                    12.0         196
# 65                  1                 13                     7.0         196
# 66                  2                 15                     8.0         196
# 67                  0                  9                    25.0         196
# 68                  5                 14                     5.0         196
# 69                  3                  9                    30.0         196
# 70                  4                 13                    15.0         196
# 71                  6                 13                    30.0         196
# 72                  4                 11                    30.0         196
# 73                  5                  8                     8.0         196
# 74                  3                 17                     9.0         196
# 75                  3                 11                     NaN         196
# 76                  2                  8                    19.0         196
# 77                  1                 12                    25.0         196
# 78                  1                 14                     NaN         196
# 79                  1                  9                     4.0         196
# 80                  5                 11                     3.0         196
# 81                  5                 10                     7.0         196
# 82                  1                 14                     4.0         196
# 83                  2                  8                     4.0         196
# 84                  3                 10                     6.0         196
# 85                  2                 15                     0.0         196
# 86                  3                 16                     2.0         196
# 87                  5                 10                     2.0         196
# 88                  3                 12                     2.0         196
# 89                  4                 11                     3.0         196
# 90                  2                 12                     1.0         196
# 91                  5                 15                     1.0         196
# 92                  5                 19                     6.0         196
# 93                  6                 10                     7.0         196
# 94                  5                 16                    30.0         196
# 95                  5                 12                     NaN         196
# 96                  5                 17                     3.0         196
# 97                  4                 10                    22.0         196
# 98                  1                 19                    30.0         196
# 99                  3                 19                    16.0         196
#
#     ...  product_name  aisle_id department_id  prices  _merge  \
# 0   ...          Soda        77             7     9.0    both
# 1   ...          Soda        77             7     9.0    both
# 2   ...          Soda        77             7     9.0    both
# 3   ...          Soda        77             7     9.0    both
# 4   ...          Soda        77             7     9.0    both
# 5   ...          Soda        77             7     9.0    both
# 6   ...          Soda        77             7     9.0    both
# 7   ...          Soda        77             7     9.0    both
# 8   ...          Soda        77             7     9.0    both
# 9   ...          Soda        77             7     9.0    both
# 10  ...          Soda        77             7     9.0    both
# 11  ...          Soda        77             7     9.0    both
# 12  ...          Soda        77             7     9.0    both
# 13  ...          Soda        77             7     9.0    both
# 14  ...          Soda        77             7     9.0    both
# 15  ...          Soda        77             7     9.0    both
# 16  ...          Soda        77             7     9.0    both
# 17  ...          Soda        77             7     9.0    both
# 18  ...          Soda        77             7     9.0    both
# 19  ...          Soda        77             7     9.0    both
# 20  ...          Soda        77             7     9.0    both
# 21  ...          Soda        77             7     9.0    both
# 22  ...          Soda        77             7     9.0    both
# 23  ...          Soda        77             7     9.0    both
# 24  ...          Soda        77             7     9.0    both
# 25  ...          Soda        77             7     9.0    both
# 26  ...          Soda        77             7     9.0    both
# 27  ...          Soda        77             7     9.0    both
# 28  ...          Soda        77             7     9.0    both
# 29  ...          Soda        77             7     9.0    both
# 30  ...          Soda        77             7     9.0    both
# 31  ...          Soda        77             7     9.0    both
# 32  ...          Soda        77             7     9.0    both
# 33  ...          Soda        77             7     9.0    both
# 34  ...          Soda        77             7     9.0    both
# 35  ...          Soda        77             7     9.0    both
# 36  ...          Soda        77             7     9.0    both
# 37  ...          Soda        77             7     9.0    both
# 38  ...          Soda        77             7     9.0    both
# 39  ...          Soda        77             7     9.0    both
# 40  ...          Soda        77             7     9.0    both
# 41  ...          Soda        77             7     9.0    both
# 42  ...          Soda        77             7     9.0    both
# 43  ...          Soda        77             7     9.0    both
# 44  ...          Soda        77             7     9.0    both
# 45  ...          Soda        77             7     9.0    both
# 46  ...          Soda        77             7     9.0    both
# 47  ...          Soda        77             7     9.0    both
# 48  ...          Soda        77             7     9.0    both
# 49  ...          Soda        77             7     9.0    both
# 50  ...          Soda        77             7     9.0    both
# 51  ...          Soda        77             7     9.0    both
# 52  ...          Soda        77             7     9.0    both
# 53  ...          Soda        77             7     9.0    both
# 54  ...          Soda        77             7     9.0    both
# 55  ...          Soda        77             7     9.0    both
# 56  ...          Soda        77             7     9.0    both
# 57  ...          Soda        77             7     9.0    both
# 58  ...          Soda        77             7     9.0    both
# 59  ...          Soda        77             7     9.0    both
# 60  ...          Soda        77             7     9.0    both
# 61  ...          Soda        77             7     9.0    both
# 62  ...          Soda        77             7     9.0    both
# 63  ...          Soda        77             7     9.0    both
# 64  ...          Soda        77             7     9.0    both
# 65  ...          Soda        77             7     9.0    both
# 66  ...          Soda        77             7     9.0    both
# 67  ...          Soda        77             7     9.0    both
# 68  ...          Soda        77             7     9.0    both
# 69  ...          Soda        77             7     9.0    both
# 70  ...          Soda        77             7     9.0    both
# 71  ...          Soda        77             7     9.0    both
# 72  ...          Soda        77             7     9.0    both
# 73  ...          Soda        77             7     9.0    both
# 74  ...          Soda        77             7     9.0    both
# 75  ...          Soda        77             7     9.0    both
# 76  ...          Soda        77             7     9.0    both
# 77  ...          Soda        77             7     9.0    both
# 78  ...          Soda        77             7     9.0    both
# 79  ...          Soda        77             7     9.0    both
# 80  ...          Soda        77             7     9.0    both
# 81  ...          Soda        77             7     9.0    both
# 82  ...          Soda        77             7     9.0    both
# 83  ...          Soda        77             7     9.0    both
# 84  ...          Soda        77             7     9.0    both
# 85  ...          Soda        77             7     9.0    both
# 86  ...          Soda        77             7     9.0    both
# 87  ...          Soda        77             7     9.0    both
# 88  ...          Soda        77             7     9.0    both
# 89  ...          Soda        77             7     9.0    both
# 90  ...          Soda        77             7     9.0    both
# 91  ...          Soda        77             7     9.0    both
# 92  ...          Soda        77             7     9.0    both
# 93  ...          Soda        77             7     9.0    both
# 94  ...          Soda        77             7     9.0    both
# 95  ...          Soda        77             7     9.0    both
# 96  ...          Soda        77             7     9.0    both
# 97  ...          Soda        77             7     9.0    both
# 98  ...          Soda        77             7     9.0    both
# 99  ...          Soda        77             7     9.0    both
#
#       price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly days        Average orders
# 1   Mid-range product  Regularly busy    Slowest days        Average orders
# 2   Mid-range product  Regularly busy    Slowest days           Most orders
# 3   Mid-range product      Least busy    Slowest days        Average orders
# 4   Mid-range product      Least busy    Slowest days           Most orders
# 5   Mid-range product  Regularly busy  Regularly days        Average orders
# 6   Mid-range product  Regularly busy    Busiest days        Average orders
# 7   Mid-range product  Regularly busy    Busiest days           Most orders
# 8   Mid-range product  Regularly busy    Busiest days        Average orders
# 9   Mid-range product      Least busy    Slowest days        Average orders
# 10  Mid-range product  Regularly busy    Busiest days        Average orders
# 11  Mid-range product  Regularly busy  Regularly days        Average orders
# 12  Mid-range product  Regularly busy  Regularly days           Most orders
# 13  Mid-range product  Regularly busy    Busiest days        Average orders
# 14  Mid-range product  Regularly busy    Busiest days           Most orders
# 15  Mid-range product  Regularly busy  Regularly days           Most orders
# 16  Mid-range product  Regularly busy  Regularly days           Most orders
# 17  Mid-range product      Least busy    Slowest days        Average orders
# 18  Mid-range product  Regularly busy    Slowest days           Most orders
# 19  Mid-range product  Regularly busy    Slowest days        Average orders
# 20  Mid-range product  Regularly busy    Slowest days           Most orders
# 21  Mid-range product      Least busy    Slowest days        Average orders
# 22  Mid-range product      Least busy    Slowest days           Most orders
# 23  Mid-range product  Regularly busy    Busiest days        Average orders
# 24  Mid-range product  Regularly busy    Busiest days           Most orders
# 25  Mid-range product  Regularly busy    Busiest days           Most orders
# 26  Mid-range product  Regularly busy  Regularly days           Most orders
# 27  Mid-range product  Regularly busy  Regularly days        Average orders
# 28  Mid-range product  Regularly busy    Busiest days           Most orders
# 29  Mid-range product  Regularly busy  Regularly days           Most orders
# 30  Mid-range product  Regularly busy  Regularly days        Average orders
# 31  Mid-range product  Regularly busy    Busiest days        Average orders
# 32  Mid-range product  Regularly busy  Regularly days           Most orders
# 33  Mid-range product  Regularly busy  Regularly days           Most orders
# 34  Mid-range product  Regularly busy  Regularly days           Most orders
# 35  Mid-range product  Regularly busy    Slowest days        Average orders
# 36  Mid-range product  Regularly busy  Regularly days           Most orders
# 37  Mid-range product  Regularly busy    Slowest days           Most orders
# 38  Mid-range product  Regularly busy    Busiest days           Most orders
# 39  Mid-range product  Regularly busy    Busiest days           Most orders
# 40  Mid-range product  Regularly busy  Regularly days        Average orders
# 41  Mid-range product  Regularly busy    Slowest days           Most orders
# 42  Mid-range product  Regularly busy    Slowest days           Most orders
# 43  Mid-range product  Regularly busy  Regularly days           Most orders
# 44  Mid-range product  Regularly busy  Regularly days           Most orders
# 45  Mid-range product  Regularly busy    Busiest days           Most orders
# 46  Mid-range product  Regularly busy    Busiest days           Most orders
# 47  Mid-range product  Regularly busy  Regularly days           Most orders
# 48  Mid-range product  Regularly busy    Busiest days           Most orders
# 49  Mid-range product  Regularly busy    Busiest days        Average orders
# 50  Mid-range product      Least busy    Slowest days           Most orders
# 51  Mid-range product  Regularly busy  Regularly days        Average orders
# 52  Mid-range product     Busiest day    Busiest days           Most orders
# 53  Mid-range product  Regularly busy    Busiest days        Average orders
# 54  Mid-range product  Regularly busy    Busiest days           Most orders
# 55  Mid-range product  Regularly busy    Busiest days           Most orders
# 56  Mid-range product  Regularly busy    Busiest days        Average orders
# 57  Mid-range product  Regularly busy  Regularly days        Average orders
# 58  Mid-range product  Regularly busy    Slowest days           Most orders
# 59  Mid-range product  Regularly busy  Regularly days           Most orders
# 60  Mid-range product     Busiest day    Busiest days           Most orders
# 61  Mid-range product      Least busy    Slowest days        Average orders
# 62  Mid-range product  Regularly busy    Busiest days           Most orders
# 63  Mid-range product  Regularly busy  Regularly days           Most orders
# 64  Mid-range product  Regularly busy  Regularly days           Most orders
# 65  Mid-range product  Regularly busy    Busiest days           Most orders
# 66  Mid-range product  Regularly busy  Regularly days           Most orders
# 67  Mid-range product     Busiest day    Busiest days        Average orders
# 68  Mid-range product  Regularly busy  Regularly days           Most orders
# 69  Mid-range product  Regularly busy    Slowest days        Average orders
# 70  Mid-range product      Least busy    Slowest days           Most orders
# 71  Mid-range product  Regularly busy  Regularly days           Most orders
# 72  Mid-range product      Least busy    Slowest days           Most orders
# 73  Mid-range product  Regularly busy  Regularly days        Average orders
# 74  Mid-range product  Regularly busy    Slowest days        Average orders
# 75  Mid-range product  Regularly busy    Slowest days           Most orders
# 76  Mid-range product  Regularly busy  Regularly days        Average orders
# 77  Mid-range product  Regularly busy    Busiest days           Most orders
# 78  Mid-range product  Regularly busy    Busiest days           Most orders
# 79  Mid-range product  Regularly busy    Busiest days        Average orders
# 80  Mid-range product  Regularly busy  Regularly days           Most orders
# 81  Mid-range product  Regularly busy  Regularly days           Most orders
# 82  Mid-range product  Regularly busy    Busiest days           Most orders
# 83  Mid-range product  Regularly busy  Regularly days        Average orders
# 84  Mid-range product  Regularly busy    Slowest days           Most orders
# 85  Mid-range product  Regularly busy  Regularly days           Most orders
# 86  Mid-range product  Regularly busy    Slowest days        Average orders
# 87  Mid-range product  Regularly busy  Regularly days           Most orders
# 88  Mid-range product  Regularly busy    Slowest days           Most orders
# 89  Mid-range product      Least busy    Slowest days           Most orders
# 90  Mid-range product  Regularly busy  Regularly days           Most orders
# 91  Mid-range product  Regularly busy  Regularly days           Most orders
# 92  Mid-range product  Regularly busy  Regularly days        Average orders
# 93  Mid-range product  Regularly busy  Regularly days           Most orders
# 94  Mid-range product  Regularly busy  Regularly days        Average orders
# 95  Mid-range product  Regularly busy  Regularly days           Most orders
# 96  Mid-range product  Regularly busy  Regularly days        Average orders
# 97  Mid-range product      Least busy    Slowest days           Most orders
# 98  Mid-range product  Regularly busy    Busiest days        Average orders
# 99  Mid-range product  Regularly busy    Slowest days        Average orders
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10
# 5         10
# 6         10
# 7         10
# 8         10
# 9         10
# 10        22
# 11        22
# 12        22
# 13        22
# 14        22
# 15         9
# 16         9
# 17         9
# 18        33
# 19        20
# 20        20
# 21        11
# 22        11
# 23        27
# 24        27
# 25        27
# 26        27
# 27        27
# 28        27
# 29        27
# 30        27
# 31        27
# 32        27
# 33        27
# 34        27
# 35        27
# 36        27
# 37        24
# 38        24
# 39        24
# 40        24
# 41        24
# 42        24
# 43        24
# 44        24
# 45        24
# 46        24
# 47        24
# 48        24
# 49        24
# 50        24
# 51        24
# 52        24
# 53        24
# 54        24
# 55        24
# 56         7
# 57         7
# 58        19
# 59        19
# 60        19
# 61        19
# 62        19
# 63        19
# 64        19
# 65        19
# 66        19
# 67        14
# 68        14
# 69        14
# 70        14
# 71        14
# 72        14
# 73        14
# 74         6
# 75         3
# 76         3
# 77         6
# 78        58
# 79        58
# 80        58
# 81        58
# 82        58
# 83        58
# 84        58
# 85        58
# 86        58
# 87        58
# 88        58
# 89        58
# 90        70
# 91        70
# 92        51
# 93        51
# 94         8
# 95         3
# 96         3
# 97         8
# 98        22
# 99        22
#
# [100 rows x 22 columns]

# %%
df_ords_merged.loc[df_ords_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_merged.loc[(df_ords_merged['max_order'] <= 40) & (df_ords_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_merged.loc[df_ords_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15877395
# Loyal customer      10284396
# New customer         6244250
# Name: loyalty_flag, dtype: int64

# %%
df_ords_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3
